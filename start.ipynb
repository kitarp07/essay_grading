# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("training_set_rel3.xlsx")
df
# Out:
#        essay_id  essay_set                                              essay  \
# 0             1          1  Dear local newspaper, I think effects computer...
# 1             2          1  Dear @CAPS1 @CAPS2, I believe that using compu...
# 2             3          1  Dear, @CAPS1 @CAPS2 @CAPS3 More and more peopl...
# 3             4          1  Dear Local Newspaper, @CAPS1 I have found that...
# 4             5          1  Dear @LOCATION1, I know having computers has a...
# ...         ...        ...                                                ...
# 12973     21626          8   In most stories mothers and daughters are eit...
# 12974     21628          8   I never understood the meaning laughter is th...
# 12975     21629          8  When you laugh, is @CAPS5 out of habit, or is ...
# 12976     21630          8                                 Trippin' on fen...
# 12977     21633          8   Many people believe that laughter can improve...
#
# ...

# %%
import pandas as pd
df7 = pd.read_csv("essay_set_7.csv")
df7.isna().sum()
# Out:
# Unnamed: 0        0
# essay_id          0
# essay_set         0
# essay             0
# rater1_domain1    0
# rater2_domain1    0
# domain1_score     0
# rater1_trait1     0
# rater1_trait2     0
# rater1_trait3     0
# rater1_trait4     0
# rater2_trait1     0
# rater2_trait2     0
# rater2_trait3     0
# rater2_trait4     0
# dtype: int64

# %%
# essay based on prompt
#scoring from 1 to 6 ---> going bad to good
# scored by two raters independently
# if two scores differ by only 1, final_score is sum of two scores else if differ by more than one, is determined by 
# expert scorer
essay_set_1 = df[df['essay_set'] == 1]
essay_set_1= essay_set_1[["essay_id", "essay_set", "essay", "rater1_domain1", "rater2_domain1", "domain1_score" ]]
# essay_set_1.to_csv("essay_set_1.csv")

# %%
# essay based on prompt
# only dataset with trait based scoring
# two traits: writing applications and language convention
#breakdown:
# writing application: Ideas and Content, Organization, Style, Voice - scored from 1- 6
# language convention: control of language skill : Scored from 1 - 4
#no provision for third resolution, 1st rater score is final_score
essay_set_2= df[df['essay_set'] == 2]
essay_set_2=  essay_set_2[["essay_id", "essay_set", "essay", "rater1_domain1", "rater2_domain1", "domain1_score", "rater1_domain2", "rater2_domain2", "domain2_score" ]]

# %%
essay_set_2.to_csv("essay_set_2.csv")

# %%
#source dependent essay
# if scores by two raters are same, no resolution required else resolution
# scored from 0-3
essay_set_3 = df[df['essay_set']==3]
essay_set_3=  essay_set_3[["essay_id", "essay_set", "essay", "rater1_domain1", "rater2_domain1", "domain1_score"]]
essay_set_3.to_csv("essay_set_3.csv")

# %%
#source dependent essay
# if scores by two raters are same, no resolution required else resolution
# scored from 0-3
essay_set_4 = df[df['essay_set']==4]
essay_set_4=  essay_set_4[["essay_id", "essay_set", "essay", "rater1_domain1", "rater2_domain1", "domain1_score"]]
essay_set_4.to_csv("essay_set_4.csv")

# %%
#source dependent essay
# •	For the specific set of data, if there was a difference between scorer 1 and scorer 2, 
# the FINAL SCORE was always the higher of the two.
# scored from 0-4
essay_set_5 = df[df['essay_set']==5]
essay_set_5=  essay_set_5[["essay_id", "essay_set", "essay", "rater1_domain1", "rater2_domain1", "domain1_score"]]
essay_set_5.to_csv("essay_set_5.csv")

# %%
#source dependent essay
# •	For the specific set of data, if there was a difference between scorer 1 and scorer 2, 
# the FINAL SCORE was always the higher of the two.
# scored from 0-4
essay_set_6 = df[df['essay_set']==6]
essay_set_6=  essay_set_6[["essay_id", "essay_set", "essay", "rater1_domain1", "rater2_domain1", "domain1_score"]]
essay_set_6.to_csv("essay_set_6.csv")

# %%
essay_set_6
# Out:
#        essay_id  essay_set                                              essay  \
# 8886      14834          6  There were many obstacles that the builders fa...
# 8887      14835          6  Him from the start, there would have been many...
# 8888      14836          6  The builders of the Empire State Building face...
# 8889      14837          6  In the passage The Mooring Mast by Marcia Amid...
# 8890      14838          6  The builders of the Empire State Building face...
# ...         ...        ...                                                ...
# 10681     16629          6  The one obstacle the builders had when trying ...
# 10682     16630          6  Some of the problems with the constructing of ...
# 10683     16631          6  The builders of the Empire State building face...
# 10684     16632          6  The obstacles the builders of the Empire State...
# 10685     16633          6  You want me to tell you what they had to go th...
#
# ...

# %%
#prompt based essay
# rating of 0-3 for four traits:
# ideas - pointed doubled for this trait
#organization
# style
# conventions
# scored from 0-15 by two raters, final_score with range 0-30 = rater-1 + rater +2

essay_set_7 = df[df['essay_set']==7]
essay_set_7.iloc[0]
essay_set_7=  essay_set_7[["essay_id", "essay_set", "essay", 
                           "rater1_domain1", "rater2_domain1", "domain1_score",
                           "rater1_trait1", "rater1_trait2", "rater1_trait3", "rater1_trait4",
                           "rater2_trait1", "rater2_trait2", "rater2_trait3", "rater2_trait4",

                           
                           ]]
essay_set_7.to_csv("essay_set_7.csv")

# %%
#prompt based essay
# rating of 1-6 for four traits:
# ideas and content
# organization
# voice
# word choice
# sentence fluency
# convention
# scored from 0- 30  by two raters, final_score with range 0-60 = adjudication rule

essay_set_8 = df[df['essay_set']==8]
# essay_set_8=  essay_set_8[["essay_id", "essay_set", "essay", 
#                            "rater1_domain1", "rater2_domain1", "domain1_score",
#                            "rater1_trait1", "rater1_trait2", "rater1_trait3", "rater1_trait4","rater1_trait5","rater1_trait6",
#                            "rater2_trait1", "rater2_trait2", "rater2_trait3", "rater2_trait4", "rater2_trait5","rater2_trait6",

                           
#                            ]]
essay_set_8.columns, essay_set_8
# Out:
# (Index(['essay_id', 'essay_set', 'essay', 'rater1_domain1', 'rater2_domain1',
#         'rater3_domain1', 'domain1_score', 'rater1_domain2', 'rater2_domain2',
#         'domain2_score', 'rater1_trait1', 'rater1_trait2', 'rater1_trait3',
#         'rater1_trait4', 'rater1_trait5', 'rater1_trait6', 'rater2_trait1',
#         'rater2_trait2', 'rater2_trait3', 'rater2_trait4', 'rater2_trait5',
#         'rater2_trait6', 'rater3_trait1', 'rater3_trait2', 'rater3_trait3',
#         'rater3_trait4', 'rater3_trait5', 'rater3_trait6'],
#        dtype='object'),
#         essay_id  essay_set                                              essay  \
#  12255     20716          8   A long time ago when I was in third grade I h...
#  12256     20717          8   Softball has to be one of the single most gre...
#  12257     20718          8   Some people like making people laugh, I love ...
#  12258     20719          8   "LAUGHTER"  @CAPS1 I hang out with my friends...
# ...

# %%
essay_set_8.to_csv("essay_set_8.csv")

# %%
essays= essay_set_1["essay"]
essays
# Out:
# 0       Dear local newspaper, I think effects computer...
# 1       Dear @CAPS1 @CAPS2, I believe that using compu...
# 2       Dear, @CAPS1 @CAPS2 @CAPS3 More and more peopl...
# 3       Dear Local Newspaper, @CAPS1 I have found that...
# 4       Dear @LOCATION1, I know having computers has a...
#                               ...
# 1778    Dear @CAPS1, @CAPS2 several reasons on way I t...
# 1779    Do a adults and kids spend to much time on the...
# 1780    My opinion is that people should have computer...
# 1781    Dear readers, I think that its good and bad to...
# 1782    Dear - Local Newspaper I agree thats computers...
# Name: essay, Length: 1783, dtype: object

# %%
scores = essay_set_1["domain1_score"]
scores
# Out:
# 0        8.0
# 1        9.0
# 2        7.0
# 3       10.0
# 4        8.0
#         ...
# 1778     8.0
# 1779     7.0
# 1780     8.0
# 1781     2.0
# 1782     7.0
# Name: domain1_score, Length: 1783, dtype: float64

# %%
from sklearn.model_selection import train_test_split

train_essays, test_essays, train_scores, test_scores = train_test_split(essays, scores, test_size = 0.2, random_state = 42)

# %%
test_scores
# Out:
# 824      6.0
# 1472     6.0
# 233      8.0
# 798      9.0
# 777      9.0
#         ...
# 818      9.0
# 532      8.0
# 381      8.0
# 844     12.0
# 557      8.0
# Name: domain1_score, Length: 357, dtype: float64

# %%
#pip install transformers

# %%
pip install torch torchvision torchaudio
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.
# ...
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#    - -------------------------------------- 0.0/1.3 MB 326.8 kB/s eta 0:00:04
#    -- ------------------------------------- 0.1/1.3 MB 573.4 kB/s eta 0:00:03
#    ---- ----------------------------------- 0.2/1.3 MB 833.5 kB/s eta 0:00:02
#    -------- ------------------------------- 0.3/1.3 MB 1.1 MB/s eta 0:00:01
#    ------------ --------------------------- 0.4/1.3 MB 1.2 MB/s eta 0:00:01
#    ----------------- ---------------------- 0.6/1.3 MB 1.5 MB/s eta 0:00:01
#    ------------------------- -------------- 0.8/1.3 MB 2.0 MB/s eta 0:00:01
#    -------------------------------------- - 1.2/1.3 MB 2.7 MB/s eta 0:00:01
#    ---------------------------------------- 1.3/1.3 MB 2.7 MB/s eta 0:00:00
# ...

# %%
import torch
from transformers import BertTokenizer, BertForSequenceClassification
from sklearn.metrics import mean_squared_error, cohen_kappa_score
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 import torch
#       2 from transformers import BertTokenizer, BertForSequenceClassification
#       3 from sklearn.metrics import mean_squared_error, cohen_kappa_score
#
# File c:\Users\DELL\anaconda3\Lib\site-packages\torch\__init__.py:148
#     146                 err = ctypes.WinError(ctypes.get_last_error())
#     147                 err.strerror += f' Error loading "{dll}" or one of its dependencies.'
# --> 148                 raise err
#     150     kernel32.SetErrorMode(prev_error_mode)
#     153 def _preload_cuda_deps(lib_folder, lib_name):
#
# OSError: [WinError 126] The specified module could not be found. Error loading "c:\Users\DELL\anaconda3\Lib\site-packages\torch\lib\fbgemm.dll" or one of its dependencies.

# %%
tokenizer =  BertTokenizer.from_pretrained('bert-base-uncased')

encoded_essays

# %%
import pandas as pd

# %%
df_1 = pd.read_csv("df_with_features_set_1.csv")
df_1["overall_score"] = df_1["domain1_score"]
df_1
#domain1_score
# Out:
#       Unnamed: 0.1  Unnamed: 0  essay_id  essay_set  \
# 0                0           0         1          1
# 1                1           1         2          1
# 2                2           2         3          1
# 3                3           3         4          1
# 4                4           4         5          1
# ...            ...         ...       ...        ...
# 1778          1778        1778      1783          1
# 1779          1779        1779      1784          1
# 1780          1780        1780      1785          1
# 1781          1781        1781      1786          1
# 1782          1782        1782      1787          1
#
#                                                   essay  rater1_domain1  \
# 0     Dear local newspaper, I think effects computer...             4.0
# 1     Dear @CAPS1 @CAPS2, I believe that using compu...             5.0
# 2     Dear, @CAPS1 @CAPS2 @CAPS3 More and more peopl...             4.0
# ...

# %%
df_2 = pd.read_csv("df_with_features_set_2.csv")
df_2["overall_score"] = df_2["domain1_score"] + df_2["domain2_score"]
df_2
#domain1_score + domain2_score
# Out:
#       Unnamed: 0  essay_id  essay_set  \
# 0              0      2978          2
# 1              1      2979          2
# 2              2      2980          2
# 3              3      2981          2
# 4              4      2982          2
# ...          ...       ...        ...
# 1795        1795      4773          2
# 1796        1796      4774          2
# 1797        1797      4775          2
# 1798        1798      4776          2
# 1799        1799      4777          2
#
#                                                   essay  rater1_domain1  \
# 0     Certain materials being removed from libraries...             4.0
# 1     Write a persuasive essay to a newspaper reflec...             1.0
# 2     Do you think that libraries should remove cert...             2.0
# 3     In @DATE1's world, there are many things found...             4.0
# 4     In life you have the 'offensive things'. The l...             4.0
# ...

# %%
df_3 = pd.read_csv("df_with_features_set_3.csv")
df_3.columns
df_3["overall_score"] = df_3["domain1_score"]
df_3
#domain_1_score
# Out:
#       Unnamed: 0  essay_id  essay_set  \
# 0              0      5978          3
# 1              1      5979          3
# 2              2      5980          3
# 3              3      5981          3
# 4              4      5982          3
# ...          ...       ...        ...
# 1721        1721      7704          3
# 1722        1722      7705          3
# 1723        1723      7706          3
# 1724        1724      7707          3
# 1725        1725      7708          3
#
#                                                   essay  rater1_domain1  \
# 0     The features of the setting affect the cyclist...             1.0
# 1     The features of the setting affected the cycli...             2.0
# 2     Everyone travels to unfamiliar places. Sometim...             1.0
# 3     I believe the features of the cyclist affected...             1.0
# 4     The setting effects the cyclist because of the...             2.0
# ...

# %%
df_4 = pd.read_csv("df_with_features_set_4.csv")
df_4["overall_score"] = df_4["domain1_score"]
df_4
#domain_1_score
# Out:
#       Unnamed: 0  essay_id  essay_set  \
# 0              0      8863          4
# 1              1      8864          4
# 2              2      8865          4
# 3              3      8866          4
# 4              4      8867          4
# ...          ...       ...        ...
# 1767        1767     10638          4
# 1768        1768     10639          4
# 1769        1769     10640          4
# 1770        1770     10641          4
# 1771        1771     10642          4
#
#                                                   essay  rater1_domain1  \
# 0     The author concludes the story with this becau...             0.0
# 1     The narrater has that in with Paragraph becuse...             0.0
# 2     The author concludes the story with that passa...             3.0
# 3     The author ended the story with this paragraph...             1.0
# 4     The author concludes the story with this parag...             2.0
# ...

# %%
df_5= pd.read_csv("df_with_features_set_5.csv")
df_5["overall_score"] = df_5["domain1_score"]
df_5
#domain_1_score
# Out:
#       Unnamed: 0  essay_id  essay_set  \
# 0              0     11827          5
# 1              1     11828          5
# 2              2     11829          5
# 3              3     11830          5
# 4              4     11831          5
# ...          ...       ...        ...
# 1800        1800     13627          5
# 1801        1801     13628          5
# 1802        1802     13629          5
# 1803        1803     13630          5
# 1804        1804     13631          5
#
#                                                   essay  rater1_domain1  \
# 0     In this memoir of Narciso Rodriguez, @PERSON3'...             2.0
# 1     Throughout the excerpt from Home the Blueprint...             2.0
# 2     The mood the author created in the memoir is l...             3.0
# 3     The mood created by the author is showing how ...             1.0
# 4     The mood created in the memoir is happiness an...             2.0
# ...

# %%
df_6 = pd.read_csv("df_with_features_set_6_2.csv")
df_6["overall_score"] = df_6["domain1_score"]
df_6
#domain_1_score
# Out:
#       Unnamed: 0  essay_id  essay_set  \
# 0              0     14834          6
# 1              1     14835          6
# 2              2     14836          6
# 3              3     14837          6
# 4              4     14838          6
# ...          ...       ...        ...
# 1795        1795     16629          6
# 1796        1796     16630          6
# 1797        1797     16631          6
# 1798        1798     16632          6
# 1799        1799     16633          6
#
#                                                   essay  rater1_domain1  \
# 0     There were many obstacles that the builders fa...             2.0
# 1     Him from the start, there would have been many...             3.0
# 2     The builders of the Empire State Building face...             3.0
# 3     In the passage The Mooring Mast by Marcia Amid...             1.0
# 4     The builders of the Empire State Building face...             3.0
# ...

# %%
df_7 = pd.read_csv("df_with_features_set_7_2.csv")
df_7["overall_score"] = df_7["domain1_score"]
df_7
#domain_1_score
# Out:
#       Unnamed: 0.1  Unnamed: 0  essay_id  essay_set  \
# 0                0           0     17834          7
# 1                1           1     17836          7
# 2                2           2     17837          7
# 3                3           3     17838          7
# 4                4           4     17839          7
# ...            ...         ...       ...        ...
# 1564          1564        1564     19558          7
# 1565          1565        1565     19559          7
# 1566          1566        1566     19561          7
# 1567          1567        1567     19562          7
# 1568          1568        1568     19563          7
#
#                                                   essay  rater1_domain1  \
# 0     Patience is when your waiting .I was patience ...             8.0
# 1     I am not a patience person, like I can’t sit i...             6.0
# 2     One day I was at basketball practice and I was...             7.0
# ...

# %%
df_8 = pd.read_csv("df_with_features_set_8.csv")
df_8["overall_score"] = df_8["domain1_score"]
df_8
#domain_1_score
# Out:
#      Unnamed: 0  essay_id  essay_set  \
# 0             0     20716          8
# 1             1     20717          8
# 2             2     20718          8
# 3             3     20719          8
# 4             4     20721          8
# ..          ...       ...        ...
# 718         718     21626          8
# 719         719     21628          8
# 720         720     21629          8
# 721         721     21630          8
# 722         722     21633          8
#
#                                                  essay  rater1_domain1  \
# 0     A long time ago when I was in third grade I h...            18.0
# 1     Softball has to be one of the single most gre...            21.0
# 2     Some people like making people laugh, I love ...            15.0
# 3     "LAUGHTER"  @CAPS1 I hang out with my friends...            12.0
# 4    Well ima tell a story about the time i got @CA...            11.0
# ..                                                 ...             ...
# ...

# %%
df_11 = df_1[['essay_set', 'essay',
       'num_grammatical_errors', 'adjacent_sentence_similarity',
       'lexical_repetition_ratio', 'unique_lemmas_count', 'pronoun_count',
       'avg_sentence_length', 'sentence_length_std',
       'discourse_connective_count', 'vocabulary_richness',
       'semantic_relevance', 'flesch_reading_ease', 'flesch_kincaid_grade',
       'gunning_fog_index', 'smog_index', 'automated_readability_index',
       'coleman_liau_index', 'overall_score']]
df_11
# Out:
#       essay_set                                              essay  \
# 0             1  Dear local newspaper, I think effects computer...
# 1             1  Dear @CAPS1 @CAPS2, I believe that using compu...
# 2             1  Dear, @CAPS1 @CAPS2 @CAPS3 More and more peopl...
# 3             1  Dear Local Newspaper, @CAPS1 I have found that...
# 4             1  Dear @LOCATION1, I know having computers has a...
# ...         ...                                                ...
# 1778          1  Dear @CAPS1, @CAPS2 several reasons on way I t...
# 1779          1  Do a adults and kids spend to much time on the...
# 1780          1  My opinion is that people should have computer...
# 1781          1  Dear readers, I think that its good and bad to...
# 1782          1  Dear - Local Newspaper I agree thats computers...
#
#       num_grammatical_errors  adjacent_sentence_similarity  \
# 0                         17                      0.675950
# ...

# %%
df_22 = df_2[['essay_set', 'essay', 'num_grammatical_errors',
       'adjacent_sentence_similarity', 'lexical_repetition_ratio',
       'unique_lemmas_count', 'pronoun_count', 'avg_sentence_length',
       'sentence_length_std', 'discourse_connective_count',
       'vocabulary_richness', 'semantic_relevance', 'flesch_reading_ease',
       'flesch_kincaid_grade', 'gunning_fog_index', 'smog_index',
       'automated_readability_index', 'coleman_liau_index', 'overall_score']]
df_22
# Out:
#       essay_set                                              essay  \
# 0             2  Certain materials being removed from libraries...
# 1             2  Write a persuasive essay to a newspaper reflec...
# 2             2  Do you think that libraries should remove cert...
# 3             2  In @DATE1's world, there are many things found...
# 4             2  In life you have the 'offensive things'. The l...
# ...         ...                                                ...
# 1795          2  The author is writting about taking books off ...
# 1796          2  I do not think that materials, such as books, ...
# 1797          2  Yes we should keep the books,music,movies,an m...
# 1798          2  I do believe that  book, magazines, music, mov...
# 1799          2  Different Then Everyone Else     @CAPS1 do peo...
#
#       num_grammatical_errors  adjacent_sentence_similarity  \
# 0                         14                      0.733187
# ...

# %%
df_33 = df_3[['essay_set', 'essay', 'num_grammatical_errors',
       'adjacent_sentence_similarity', 'lexical_repetition_ratio',
       'unique_lemmas_count', 'pronoun_count', 'avg_sentence_length',
       'sentence_length_std', 'discourse_connective_count',
       'vocabulary_richness', 'semantic_relevance', 'flesch_reading_ease',
       'flesch_kincaid_grade', 'gunning_fog_index', 'smog_index',
       'automated_readability_index', 'coleman_liau_index', 'overall_score']]
df_33
# Out:
#       essay_set                                              essay  \
# 0             3  The features of the setting affect the cyclist...
# 1             3  The features of the setting affected the cycli...
# 2             3  Everyone travels to unfamiliar places. Sometim...
# 3             3  I believe the features of the cyclist affected...
# 4             3  The setting effects the cyclist because of the...
# ...         ...                                                ...
# 1721          3  In the story, the setting affected the cyclist...
# 1722          3  The features of the setting affect the cyclist...
# 1723          3  The setting greatly affects the cyclist trying...
# 1724          3  The features of the setting affected the cycli...
# 1725          3  The features of the setting in “Rough Road Ahe...
#
#       num_grammatical_errors  adjacent_sentence_similarity  \
# 0                          1                      0.753816
# ...

# %%
df_44 = df_4[['essay_set', 'essay', 'num_grammatical_errors',
       'adjacent_sentence_similarity', 'lexical_repetition_ratio',
       'unique_lemmas_count', 'pronoun_count', 'avg_sentence_length',
       'sentence_length_std', 'discourse_connective_count',
       'vocabulary_richness', 'semantic_relevance', 'flesch_reading_ease',
       'flesch_kincaid_grade', 'gunning_fog_index', 'smog_index',
       'automated_readability_index', 'coleman_liau_index', 'overall_score']]
df_44
# Out:
#       essay_set                                              essay  \
# 0             4  The author concludes the story with this becau...
# 1             4  The narrater has that in with Paragraph becuse...
# 2             4  The author concludes the story with that passa...
# 3             4  The author ended the story with this paragraph...
# 4             4  The author concludes the story with this parag...
# ...         ...                                                ...
# 1767          4  To me it seam like the whoever was saying that...
# 1768          4  The author concludes the story with this becau...
# 1769          4  The author uses this conclusion for a reason. ...
# 1770          4  The author concludes the story with this parag...
# 1771          4  There was a specific reason as to why the auth...
#
#       num_grammatical_errors  adjacent_sentence_similarity  \
# 0                          5                      0.731869
# ...

# %%
df_55 = df_5[['essay_set', 'essay', 'num_grammatical_errors',
       'adjacent_sentence_similarity', 'lexical_repetition_ratio',
       'unique_lemmas_count', 'pronoun_count', 'avg_sentence_length',
       'sentence_length_std', 'discourse_connective_count',
       'vocabulary_richness', 'semantic_relevance', 'flesch_reading_ease',
       'flesch_kincaid_grade', 'gunning_fog_index', 'smog_index',
       'automated_readability_index', 'coleman_liau_index', 'overall_score']]
df_55
# Out:
#       essay_set                                              essay  \
# 0             5  In this memoir of Narciso Rodriguez, @PERSON3'...
# 1             5  Throughout the excerpt from Home the Blueprint...
# 2             5  The mood the author created in the memoir is l...
# 3             5  The mood created by the author is showing how ...
# 4             5  The mood created in the memoir is happiness an...
# ...         ...                                                ...
# 1800          5  The mood of this memoir is nonfiction. The moo...
# 1801          5  The mood was created by the author in the memo...
# 1802          5  In the memoir "Narciso Rodriguez", the mood cr...
# 1803          5  The mood created @CAPS3 the author, Narciso Ro...
# 1804          5  The author created such a specific mood for th...
#
#       num_grammatical_errors  adjacent_sentence_similarity  \
# 0                          6                      0.643429
# ...

# %%
df_66 = df_6[['essay_set', 'essay', 'num_grammatical_errors',
       'adjacent_sentence_similarity', 'lexical_repetition_ratio',
       'unique_lemmas_count', 'pronoun_count', 'avg_sentence_length',
       'sentence_length_std', 'discourse_connective_count',
       'vocabulary_richness', 'semantic_relevance', 'flesch_reading_ease',
       'flesch_kincaid_grade', 'gunning_fog_index', 'smog_index',
       'automated_readability_index', 'coleman_liau_index', 'overall_score']]
df_66
# Out:
#       essay_set                                              essay  \
# 0             6  There were many obstacles that the builders fa...
# 1             6  Him from the start, there would have been many...
# 2             6  The builders of the Empire State Building face...
# 3             6  In the passage The Mooring Mast by Marcia Amid...
# 4             6  The builders of the Empire State Building face...
# ...         ...                                                ...
# 1795          6  The one obstacle the builders had when trying ...
# 1796          6  Some of the problems with the constructing of ...
# 1797          6  The builders of the Empire State building face...
# 1798          6  The obstacles the builders of the Empire State...
# 1799          6  You want me to tell you what they had to go th...
#
#       num_grammatical_errors  adjacent_sentence_similarity  \
# 0                          3                      0.658530
# ...

# %%
df_77 = df_7[['essay_set', 'essay', 'num_grammatical_errors',
       'adjacent_sentence_similarity', 'lexical_repetition_ratio',
       'unique_lemmas_count', 'pronoun_count', 'avg_sentence_length',
       'sentence_length_std', 'discourse_connective_count',
       'vocabulary_richness', 'semantic_relevance', 'flesch_reading_ease',
       'flesch_kincaid_grade', 'gunning_fog_index', 'smog_index',
       'automated_readability_index', 'coleman_liau_index', 'overall_score']]
df_77
# Out:
#       essay_set                                              essay  \
# 0             7  Patience is when your waiting .I was patience ...
# 1             7  I am not a patience person, like I can’t sit i...
# 2             7  One day I was at basketball practice and I was...
# 3             7  I going to write about a time when I went to t...
# 4             7  It can be very hard for somebody to be patient...
# ...         ...                                                ...
# 1564          7  One time I was getting a cool @CAPS1 game it w...
# 1565          7  A patent person in my life is my mom. Aicason ...
# 1566          7  A time when someone else I know was patient wa...
# 1567          7  I hate weddings. I love when people get marrie...
# 1568          7  A few weeks ago, we had a garage sale and a mo...
#
#       num_grammatical_errors  adjacent_sentence_similarity  \
# 0                         20                      0.723575
# ...

# %%
df_88 = df_8[['essay_set', 'essay', 'num_grammatical_errors',
       'adjacent_sentence_similarity', 'lexical_repetition_ratio',
       'unique_lemmas_count', 'pronoun_count', 'avg_sentence_length',
       'sentence_length_std', 'discourse_connective_count',
       'vocabulary_richness', 'semantic_relevance', 'flesch_reading_ease',
       'flesch_kincaid_grade', 'gunning_fog_index', 'smog_index',
       'automated_readability_index', 'coleman_liau_index', 'overall_score']]
df_88
# Out:
#      essay_set                                              essay  \
# 0            8   A long time ago when I was in third grade I h...
# 1            8   Softball has to be one of the single most gre...
# 2            8   Some people like making people laugh, I love ...
# 3            8   "LAUGHTER"  @CAPS1 I hang out with my friends...
# 4            8  Well ima tell a story about the time i got @CA...
# ..         ...                                                ...
# 718          8   In most stories mothers and daughters are eit...
# 719          8   I never understood the meaning laughter is th...
# 720          8  When you laugh, is @CAPS5 out of habit, or is ...
# 721          8                                 Trippin' on fen...
# 722          8   Many people believe that laughter can improve...
#
#      num_grammatical_errors  adjacent_sentence_similarity  \
# 0                        61                      0.674467
# ...

# %%
df_8.head(3)
# Out:
#    Unnamed: 0  essay_id  essay_set  \
# 0           0     20716          8
# 1           1     20717          8
# 2           2     20718          8
#
#                                                essay  rater1_domain1  \
# 0   A long time ago when I was in third grade I h...            18.0
# 1   Softball has to be one of the single most gre...            21.0
# 2   Some people like making people laugh, I love ...            15.0
#
#    rater2_domain1  domain1_score  rater1_trait1  rater1_trait2  rater1_trait3  \
# 0            16.0           34.0            4.0            4.0            4.0
# 1            26.0           46.0            5.0            4.0            5.0
# 2            20.0           40.0            3.0            3.0            3.0
#
#    ...  discourse_connective_count  vocabulary_richness  semantic_relevance  \
# 0  ...                          13             0.520505            0.707057
# ...

# %%
df_88.head(3)
# Out:
#    essay_set                                              essay  \
# 0          8   A long time ago when I was in third grade I h...
# 1          8   Softball has to be one of the single most gre...
# 2          8   Some people like making people laugh, I love ...
#
#    num_grammatical_errors  adjacent_sentence_similarity  \
# 0                      61                      0.674467
# 1                      17                      0.703512
# 2                      21                      0.707248
#
#    lexical_repetition_ratio  unique_lemmas_count  pronoun_count  \
# 0                  0.680272                  148            140
# 1                  0.633898                  163            133
# 2                  0.611446                  178            142
#
#    avg_sentence_length  sentence_length_std  discourse_connective_count  \
# 0            16.954545             9.002410                          13
# 1            23.916667            11.949837                          16
# ...

# %%
import pandas as pd

def min_max_scaling_column(df, min_value, max_value):    
    if max_value != min_value:  # Avoid division by zero
        df["scaled_score"] = (df["overall_score"] - min_value) / (max_value - min_value)
    else:
        df["scaled_score"] = 0  # If all values are the same, scale to 0
    
    return df


score_ranges = {
    1: (2, 12),  # Essay Set 1
    2: (2, 10),  # Essay Set 2
    3: (0, 3),   # Essay Set 3
    4: (0, 3),   # Essay Set 4
    5: (0, 4),   # Essay Set 5
    6: (0, 4),   # Essay Set 6
    7: (0, 30),  # Essay Set 7
    8: (0, 60)   # Essay Set 8
}

def inverse_min_max_scaling(predicted_val, essay_set):
    if essay_set in score_ranges:
        min_value, max_value = score_ranges[essay_set]
        
        if max_value != min_value:  # Avoid division by zero
            scale_up_predicted = predicted_val* (max_value - min_value) + min_value
        else:
            scale_up_predicted = min_value  # If all values were the same, original value is min_value
    else:
        raise ValueError(f"Invalid essay set number: {essay_set}")
    
    return scale_up_predicted

# %%
df_c1 = df_11
df_c1
# Out:
#       essay_set                                              essay  \
# 0             1  Dear local newspaper, I think effects computer...
# 1             1  Dear @CAPS1 @CAPS2, I believe that using compu...
# 2             1  Dear, @CAPS1 @CAPS2 @CAPS3 More and more peopl...
# 3             1  Dear Local Newspaper, @CAPS1 I have found that...
# 4             1  Dear @LOCATION1, I know having computers has a...
# ...         ...                                                ...
# 1778          1  Dear @CAPS1, @CAPS2 several reasons on way I t...
# 1779          1  Do a adults and kids spend to much time on the...
# 1780          1  My opinion is that people should have computer...
# 1781          1  Dear readers, I think that its good and bad to...
# 1782          1  Dear - Local Newspaper I agree thats computers...
#
#       num_grammatical_errors  adjacent_sentence_similarity  \
# 0                         17                      0.675950
# ...

# %%
df_scaled_1 = min_max_scaling_column(df_c1, 2, 12)
df_scaled_1.to_csv("df_scaled_1.csv")
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_13096\2594514770.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["scaled_score"] = (df["overall_score"] - min_value) / (max_value - min_value)

# %%
df_scaled_2 = min_max_scaling_column(df_22, 2, 10)
df_scaled_2.to_csv("df_scaled_2.csv")
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_13096\2594514770.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["scaled_score"] = (df["overall_score"] - min_value) / (max_value - min_value)

# %%
df_scaled_3 = min_max_scaling_column(df_33, 0, 3)
df_scaled_3.to_csv("df_scaled_3.csv")
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_13096\2594514770.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["scaled_score"] = (df["overall_score"] - min_value) / (max_value - min_value)

# %%
df_scaled_4 = min_max_scaling_column(df_44, 0, 3)
df_scaled_4.to_csv("df_scaled_4.csv")
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_13096\2594514770.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["scaled_score"] = (df["overall_score"] - min_value) / (max_value - min_value)

# %%
df_scaled_5 = min_max_scaling_column(df_55, 0, 4)
df_scaled_5.to_csv("df_scaled_5.csv")
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_13096\2594514770.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["scaled_score"] = (df["overall_score"] - min_value) / (max_value - min_value)

# %%
df_scaled_6 = min_max_scaling_column(df_66, 0, 4)
df_scaled_6.to_csv("df_scaled_6.csv")
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_13096\2594514770.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["scaled_score"] = (df["overall_score"] - min_value) / (max_value - min_value)

# %%
df_scaled_7 = min_max_scaling_column(df_77, 0, 30)
df_scaled_7.to_csv("df_scaled_7.csv")
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_13096\2594514770.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["scaled_score"] = (df["overall_score"] - min_value) / (max_value - min_value)

# %%
df_scaled_8 = min_max_scaling_column(df_88, 0, 60)
df_scaled_8.to_csv("df_scaled_8.csv")
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_13096\2594514770.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["scaled_score"] = (df["overall_score"] - min_value) / (max_value - min_value)

# %%
df_all = pd.concat([df_scaled_1, df_scaled_2, df_scaled_3, df_scaled_4, 
                    df_scaled_5, df_scaled_6, df_scaled_7, df_scaled_8], ignore_index=True)

df_all
# Out:
#        essay_set                                              essay  \
# 0              1  Dear local newspaper, I think effects computer...
# 1              1  Dear @CAPS1 @CAPS2, I believe that using compu...
# 2              1  Dear, @CAPS1 @CAPS2 @CAPS3 More and more peopl...
# 3              1  Dear Local Newspaper, @CAPS1 I have found that...
# 4              1  Dear @LOCATION1, I know having computers has a...
# ...          ...                                                ...
# 12973          8   In most stories mothers and daughters are eit...
# 12974          8   I never understood the meaning laughter is th...
# 12975          8  When you laugh, is @CAPS5 out of habit, or is ...
# 12976          8                                 Trippin' on fen...
# 12977          8   Many people believe that laughter can improve...
#
#        num_grammatical_errors  adjacent_sentence_similarity  \
# 0                          17                      0.675950
# ...

# %%
df_all.to_csv("all_scaled.csv")

# %%
df_all["scaled_score"].min()
# Out:
# 0.0

# %%
df_all.isna().sum()
# Out:
# essay_set                       0
# essay                           0
# num_grammatical_errors          0
# adjacent_sentence_similarity    0
# lexical_repetition_ratio        0
# unique_lemmas_count             0
# pronoun_count                   0
# avg_sentence_length             0
# sentence_length_std             0
# discourse_connective_count      0
# vocabulary_richness             0
# semantic_relevance              0
# flesch_reading_ease             0
# flesch_kincaid_grade            0
# gunning_fog_index               0
# smog_index                      0
# automated_readability_index     0
# coleman_liau_index              0
# overall_score                   1
# scaled_score                    1
# dtype: int64

# %%
df_all_clean = df_all.dropna()
df_all_clean.isna().sum()
# Out:
# essay_set                       0
# essay                           0
# num_grammatical_errors          0
# adjacent_sentence_similarity    0
# lexical_repetition_ratio        0
# unique_lemmas_count             0
# pronoun_count                   0
# avg_sentence_length             0
# sentence_length_std             0
# discourse_connective_count      0
# vocabulary_richness             0
# semantic_relevance              0
# flesch_reading_ease             0
# flesch_kincaid_grade            0
# gunning_fog_index               0
# smog_index                      0
# automated_readability_index     0
# coleman_liau_index              0
# overall_score                   0
# scaled_score                    0
# dtype: int64

# %%
df_all_clean.to_csv("df_all.csv")

# %%
import pandas as pd 

df = pd.read_csv("test_scores.csv")
df
# Out:
#       scaled_score  overall_score  essay_set
# 0         0.333333            1.0          3
# 1         0.750000            3.0          5
# 2         0.666667            2.0          3
# 3         0.666667            2.0          3
# 4         0.500000            6.0          2
# ...            ...            ...        ...
# 2591      0.666667            2.0          4
# 2592      1.000000            4.0          6
# 2593      0.333333            1.0          3
# 2594      0.375000            5.0          2
# 2595      0.600000            8.0          1
#
# [2596 rows x 3 columns]

# %%
essay_set_totals = {
    1: 12,
    2: 10,
    3: 3,
    4: 3,
    5: 4,
    6: 4,
    7: 30,
    8: 60
}

# %%
df['total_score'] = df['essay_set'].map(essay_set_totals)
df.to_csv("test_scores_with_total.csv")

# %%
df['overall_score'] = df['overall_score'].astype(int)
df
# Out:
#       scaled_score  overall_score  essay_set  total_score
# 0         0.333333              1          3            3
# 1         0.750000              3          5            4
# 2         0.666667              2          3            3
# 3         0.666667              2          3            3
# 4         0.500000              6          2           10
# ...            ...            ...        ...          ...
# 2591      0.666667              2          4            3
# 2592      1.000000              4          6            4
# 2593      0.333333              1          3            3
# 2594      0.375000              5          2           10
# 2595      0.600000              8          1           12
#
# [2596 rows x 4 columns]

# %%
df.to_csv("test_scores_with_total.csv")

# %%
df_all = pd.read_csv("df_all.csv")
df_all.head(10).to_csv("test.csv")

# %%
# Out:
#    essay_set                                              essay  \
# 0          1  Dear local newspaper, I think effects computer...
# 1          1  Dear @CAPS1 @CAPS2, I believe that using compu...
# 2          1  Dear, @CAPS1 @CAPS2 @CAPS3 More and more peopl...
# 3          1  Dear Local Newspaper, @CAPS1 I have found that...
# 4          1  Dear @LOCATION1, I know having computers has a...
# 5          1  Dear @LOCATION1, I think that computers have a...
# 6          1  Did you know that more and more people these d...
# 7          1  @PERCENT1 of people agree that computers make ...
# 8          1  Dear reader, @ORGANIZATION1 has had a dramatic...
# 9          1  In the @LOCATION1 we have the technology of a ...
#
#    num_grammatical_errors  adjacent_sentence_similarity  \
# 0                      17                      0.675950
# 1                      24                      0.744739
# 2                      14                      0.659405
# ...

# %%
df_all['total_score'] = df_all['essay_set'].map(essay_set_totals)
df_all
# Out:
#        Unnamed: 0  essay_set  \
# 0               0          1
# 1               1          1
# 2               2          1
# 3               3          1
# 4               4          1
# ...           ...        ...
# 12972       12973          8
# 12973       12974          8
# 12974       12975          8
# 12975       12976          8
# 12976       12977          8
#
#                                                    essay  \
# 0      Dear local newspaper, I think effects computer...
# 1      Dear @CAPS1 @CAPS2, I believe that using compu...
# 2      Dear, @CAPS1 @CAPS2 @CAPS3 More and more peopl...
# 3      Dear Local Newspaper, @CAPS1 I have found that...
# 4      Dear @LOCATION1, I know having computers has a...
# ...                                                  ...
# 12972   In most stories mothers and daughters are eit...
# 12973   I never understood the meaning laughter is th...
# 12974  When you laugh, is @CAPS5 out of habit, or is ...
# ...

# %%
df_all['overall_score'] = df_all['overall_score'].astype(int)
df_all.to_csv("test.csv")
