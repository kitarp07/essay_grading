# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("training_set_rel3.xlsx")
df
# Out:
#        essay_id  essay_set                                              essay  \
# 0             1          1  Dear local newspaper, I think effects computer...
# 1             2          1  Dear @CAPS1 @CAPS2, I believe that using compu...
# 2             3          1  Dear, @CAPS1 @CAPS2 @CAPS3 More and more peopl...
# 3             4          1  Dear Local Newspaper, @CAPS1 I have found that...
# 4             5          1  Dear @LOCATION1, I know having computers has a...
# ...         ...        ...                                                ...
# 12973     21626          8   In most stories mothers and daughters are eit...
# 12974     21628          8   I never understood the meaning laughter is th...
# 12975     21629          8  When you laugh, is @CAPS5 out of habit, or is ...
# 12976     21630          8                                 Trippin' on fen...
# 12977     21633          8   Many people believe that laughter can improve...
#
#        rater1_domain1  rater2_domain1  rater3_domain1  domain1_score  \
# 0                 4.0             4.0             NaN            8.0
# 1                 5.0             4.0             NaN            9.0
# 2                 4.0             3.0             NaN            7.0
# 3                 5.0             5.0             NaN           10.0
# 4                 4.0             4.0             NaN            8.0
# ...               ...             ...             ...            ...
# 12973            17.0            18.0             NaN           35.0
# 12974            15.0            17.0             NaN           32.0
# 12975            20.0            26.0            40.0           40.0
# 12976            20.0            20.0             NaN           40.0
# 12977            20.0            20.0             NaN           40.0
#
#        rater1_domain2  rater2_domain2  domain2_score  ...  rater2_trait3  \
# 0                 NaN             NaN            NaN  ...            NaN
# 1                 NaN             NaN            NaN  ...            NaN
# 2                 NaN             NaN            NaN  ...            NaN
# 3                 NaN             NaN            NaN  ...            NaN
# 4                 NaN             NaN            NaN  ...            NaN
# ...               ...             ...            ...  ...            ...
# 12973             NaN             NaN            NaN  ...            4.0
# 12974             NaN             NaN            NaN  ...            4.0
# 12975             NaN             NaN            NaN  ...            5.0
# 12976             NaN             NaN            NaN  ...            4.0
# 12977             NaN             NaN            NaN  ...            4.0
#
#        rater2_trait4  rater2_trait5  rater2_trait6  rater3_trait1  \
# 0                NaN            NaN            NaN            NaN
# 1                NaN            NaN            NaN            NaN
# 2                NaN            NaN            NaN            NaN
# 3                NaN            NaN            NaN            NaN
# 4                NaN            NaN            NaN            NaN
# ...              ...            ...            ...            ...
# 12973            4.0            4.0            3.0            NaN
# 12974            4.0            4.0            3.0            NaN
# 12975            5.0            5.0            5.0            4.0
# 12976            4.0            4.0            4.0            NaN
# 12977            4.0            4.0            4.0            NaN
#
#        rater3_trait2  rater3_trait3  rater3_trait4  rater3_trait5  \
# 0                NaN            NaN            NaN            NaN
# 1                NaN            NaN            NaN            NaN
# 2                NaN            NaN            NaN            NaN
# 3                NaN            NaN            NaN            NaN
# 4                NaN            NaN            NaN            NaN
# ...              ...            ...            ...            ...
# 12973            NaN            NaN            NaN            NaN
# 12974            NaN            NaN            NaN            NaN
# 12975            4.0            4.0            4.0            4.0
# 12976            NaN            NaN            NaN            NaN
# 12977            NaN            NaN            NaN            NaN
#
#        rater3_trait6
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# ...              ...
# 12973            NaN
# 12974            NaN
# 12975            4.0
# 12976            NaN
# 12977            NaN
#
# [12978 rows x 28 columns]

# %%
import pandas as pd
df7 = pd.read_csv("essay_set_7.csv")
df7.isna().sum()
# Out:
# Unnamed: 0        0
# essay_id          0
# essay_set         0
# essay             0
# rater1_domain1    0
# rater2_domain1    0
# domain1_score     0
# rater1_trait1     0
# rater1_trait2     0
# rater1_trait3     0
# rater1_trait4     0
# rater2_trait1     0
# rater2_trait2     0
# rater2_trait3     0
# rater2_trait4     0
# dtype: int64

# %%
# essay based on prompt
#scoring from 1 to 6 ---> going bad to good
# scored by two raters independently
# if two scores differ by only 1, final_score is sum of two scores else if differ by more than one, is determined by 
# expert scorer
essay_set_1 = df[df['essay_set'] == 1]
essay_set_1= essay_set_1[["essay_id", "essay_set", "essay", "rater1_domain1", "rater2_domain1", "domain1_score" ]]
# essay_set_1.to_csv("essay_set_1.csv")

# %%
# essay based on prompt
# only dataset with trait based scoring
# two traits: writing applications and language convention
#breakdown:
# writing application: Ideas and Content, Organization, Style, Voice - scored from 1- 6
# language convention: control of language skill : Scored from 1 - 4
#no provision for third resolution, 1st rater score is final_score
essay_set_2= df[df['essay_set'] == 2]
essay_set_2=  essay_set_2[["essay_id", "essay_set", "essay", "rater1_domain1", "rater2_domain1", "domain1_score", "rater1_domain2", "rater2_domain2", "domain2_score" ]]

# %%
essay_set_2.to_csv("essay_set_2.csv")

# %%
#source dependent essay
# if scores by two raters are same, no resolution required else resolution
# scored from 0-3
essay_set_3 = df[df['essay_set']==3]
essay_set_3=  essay_set_3[["essay_id", "essay_set", "essay", "rater1_domain1", "rater2_domain1", "domain1_score"]]
essay_set_3.to_csv("essay_set_3.csv")

# %%
#source dependent essay
# if scores by two raters are same, no resolution required else resolution
# scored from 0-3
essay_set_4 = df[df['essay_set']==4]
essay_set_4=  essay_set_4[["essay_id", "essay_set", "essay", "rater1_domain1", "rater2_domain1", "domain1_score"]]
essay_set_4.to_csv("essay_set_4.csv")

# %%
#source dependent essay
# •	For the specific set of data, if there was a difference between scorer 1 and scorer 2, 
# the FINAL SCORE was always the higher of the two.
# scored from 0-4
essay_set_5 = df[df['essay_set']==5]
essay_set_5=  essay_set_5[["essay_id", "essay_set", "essay", "rater1_domain1", "rater2_domain1", "domain1_score"]]
essay_set_5.to_csv("essay_set_5.csv")

# %%
#source dependent essay
# •	For the specific set of data, if there was a difference between scorer 1 and scorer 2, 
# the FINAL SCORE was always the higher of the two.
# scored from 0-4
essay_set_6 = df[df['essay_set']==6]
essay_set_6=  essay_set_6[["essay_id", "essay_set", "essay", "rater1_domain1", "rater2_domain1", "domain1_score"]]
essay_set_6.to_csv("essay_set_6.csv")

# %%
essay_set_6
# Out:
#        essay_id  essay_set                                              essay  \
# 8886      14834          6  There were many obstacles that the builders fa...
# 8887      14835          6  Him from the start, there would have been many...
# 8888      14836          6  The builders of the Empire State Building face...
# 8889      14837          6  In the passage The Mooring Mast by Marcia Amid...
# 8890      14838          6  The builders of the Empire State Building face...
# ...         ...        ...                                                ...
# 10681     16629          6  The one obstacle the builders had when trying ...
# 10682     16630          6  Some of the problems with the constructing of ...
# 10683     16631          6  The builders of the Empire State building face...
# 10684     16632          6  The obstacles the builders of the Empire State...
# 10685     16633          6  You want me to tell you what they had to go th...
#
#        rater1_domain1  rater2_domain1  domain1_score
# 8886              2.0             2.0            2.0
# 8887              3.0             3.0            3.0
# 8888              3.0             4.0            4.0
# 8889              1.0             1.0            1.0
# 8890              3.0             3.0            3.0
# ...               ...             ...            ...
# 10681             2.0             0.0            0.0
# 10682             1.0             2.0            2.0
# 10683             2.0             3.0            3.0
# 10684             2.0             1.0            2.0
# 10685             2.0             2.0            2.0
#
# [1800 rows x 6 columns]

# %%
#prompt based essay
# rating of 0-3 for four traits:
# ideas - pointed doubled for this trait
#organization
# style
# conventions
# scored from 0-15 by two raters, final_score with range 0-30 = rater-1 + rater +2

essay_set_7 = df[df['essay_set']==7]
essay_set_7.iloc[0]
essay_set_7=  essay_set_7[["essay_id", "essay_set", "essay", 
                           "rater1_domain1", "rater2_domain1", "domain1_score",
                           "rater1_trait1", "rater1_trait2", "rater1_trait3", "rater1_trait4",
                           "rater2_trait1", "rater2_trait2", "rater2_trait3", "rater2_trait4",

                           
                           ]]
essay_set_7.to_csv("essay_set_7.csv")

# %%
#prompt based essay
# rating of 1-6 for four traits:
# ideas and content
# organization
# voice
# word choice
# sentence fluency
# convention
# scored from 0- 30  by two raters, final_score with range 0-60 = adjudication rule

essay_set_8 = df[df['essay_set']==8]
# essay_set_8=  essay_set_8[["essay_id", "essay_set", "essay", 
#                            "rater1_domain1", "rater2_domain1", "domain1_score",
#                            "rater1_trait1", "rater1_trait2", "rater1_trait3", "rater1_trait4","rater1_trait5","rater1_trait6",
#                            "rater2_trait1", "rater2_trait2", "rater2_trait3", "rater2_trait4", "rater2_trait5","rater2_trait6",

                           
#                            ]]
essay_set_8.columns, essay_set_8
# Out:
# (Index(['essay_id', 'essay_set', 'essay', 'rater1_domain1', 'rater2_domain1',
#         'rater3_domain1', 'domain1_score', 'rater1_domain2', 'rater2_domain2',
#         'domain2_score', 'rater1_trait1', 'rater1_trait2', 'rater1_trait3',
#         'rater1_trait4', 'rater1_trait5', 'rater1_trait6', 'rater2_trait1',
#         'rater2_trait2', 'rater2_trait3', 'rater2_trait4', 'rater2_trait5',
#         'rater2_trait6', 'rater3_trait1', 'rater3_trait2', 'rater3_trait3',
#         'rater3_trait4', 'rater3_trait5', 'rater3_trait6'],
#        dtype='object'),
#         essay_id  essay_set                                              essay  \
#  12255     20716          8   A long time ago when I was in third grade I h...
#  12256     20717          8   Softball has to be one of the single most gre...
#  12257     20718          8   Some people like making people laugh, I love ...
#  12258     20719          8   "LAUGHTER"  @CAPS1 I hang out with my friends...
#  12259     20721          8  Well ima tell a story about the time i got @CA...
#  ...         ...        ...                                                ...
#  12973     21626          8   In most stories mothers and daughters are eit...
#  12974     21628          8   I never understood the meaning laughter is th...
#  12975     21629          8  When you laugh, is @CAPS5 out of habit, or is ...
#  12976     21630          8                                 Trippin' on fen...
#  12977     21633          8   Many people believe that laughter can improve...
#
#         rater1_domain1  rater2_domain1  rater3_domain1  domain1_score  \
#  12255            18.0            16.0             NaN           34.0
#  12256            21.0            26.0            46.0           46.0
#  12257            15.0            20.0            40.0           40.0
#  12258            12.0            20.0            30.0           30.0
#  12259            11.0            15.0             NaN           26.0
#  ...               ...             ...             ...            ...
#  12973            17.0            18.0             NaN           35.0
#  12974            15.0            17.0             NaN           32.0
#  12975            20.0            26.0            40.0           40.0
#  12976            20.0            20.0             NaN           40.0
#  12977            20.0            20.0             NaN           40.0
#
#         rater1_domain2  rater2_domain2  domain2_score  ...  rater2_trait3  \
#  12255             NaN             NaN            NaN  ...            4.0
#  12256             NaN             NaN            NaN  ...            6.0
#  12257             NaN             NaN            NaN  ...            5.0
#  12258             NaN             NaN            NaN  ...            4.0
#  12259             NaN             NaN            NaN  ...            3.0
#  ...               ...             ...            ...  ...            ...
#  12973             NaN             NaN            NaN  ...            4.0
#  12974             NaN             NaN            NaN  ...            4.0
#  12975             NaN             NaN            NaN  ...            5.0
#  12976             NaN             NaN            NaN  ...            4.0
#  12977             NaN             NaN            NaN  ...            4.0
#
#         rater2_trait4  rater2_trait5  rater2_trait6  rater3_trait1  \
#  12255            4.0            3.0            3.0            NaN
#  12256            6.0            5.0            5.0            5.0
#  12257            4.0            4.0            4.0            4.0
#  12258            4.0            4.0            4.0            3.0
#  12259            3.0            3.0            3.0            NaN
#  ...              ...            ...            ...            ...
#  12973            4.0            4.0            3.0            NaN
#  12974            4.0            4.0            3.0            NaN
#  12975            5.0            5.0            5.0            4.0
#  12976            4.0            4.0            4.0            NaN
#  12977            4.0            4.0            4.0            NaN
#
#         rater3_trait2  rater3_trait3  rater3_trait4  rater3_trait5  \
#  12255            NaN            NaN            NaN            NaN
#  12256            5.0            5.0            5.0            5.0
#  12257            4.0            4.0            4.0            4.0
#  12258            3.0            3.0            3.0            3.0
#  12259            NaN            NaN            NaN            NaN
#  ...              ...            ...            ...            ...
#  12973            NaN            NaN            NaN            NaN
#  12974            NaN            NaN            NaN            NaN
#  12975            4.0            4.0            4.0            4.0
#  12976            NaN            NaN            NaN            NaN
#  12977            NaN            NaN            NaN            NaN
#
#         rater3_trait6
#  12255            NaN
#  12256            4.0
#  12257            4.0
#  12258            3.0
#  12259            NaN
#  ...              ...
#  12973            NaN
#  12974            NaN
#  12975            4.0
#  12976            NaN
#  12977            NaN
#
#  [723 rows x 28 columns])

# %%
essay_set_8.to_csv("essay_set_8.csv")

# %%
essays= essay_set_1["essay"]
essays
# Out:
# 0       Dear local newspaper, I think effects computer...
# 1       Dear @CAPS1 @CAPS2, I believe that using compu...
# 2       Dear, @CAPS1 @CAPS2 @CAPS3 More and more peopl...
# 3       Dear Local Newspaper, @CAPS1 I have found that...
# 4       Dear @LOCATION1, I know having computers has a...
#                               ...
# 1778    Dear @CAPS1, @CAPS2 several reasons on way I t...
# 1779    Do a adults and kids spend to much time on the...
# 1780    My opinion is that people should have computer...
# 1781    Dear readers, I think that its good and bad to...
# 1782    Dear - Local Newspaper I agree thats computers...
# Name: essay, Length: 1783, dtype: object

# %%
scores = essay_set_1["domain1_score"]
scores
# Out:
# 0        8.0
# 1        9.0
# 2        7.0
# 3       10.0
# 4        8.0
#         ...
# 1778     8.0
# 1779     7.0
# 1780     8.0
# 1781     2.0
# 1782     7.0
# Name: domain1_score, Length: 1783, dtype: float64

# %%
from sklearn.model_selection import train_test_split

train_essays, test_essays, train_scores, test_scores = train_test_split(essays, scores, test_size = 0.2, random_state = 42)

# %%
test_scores
# Out:
# 824      6.0
# 1472     6.0
# 233      8.0
# 798      9.0
# 777      9.0
#         ...
# 818      9.0
# 532      8.0
# 381      8.0
# 844     12.0
# 557      8.0
# Name: domain1_score, Length: 357, dtype: float64

# %%
#pip install transformers

# %%
pip install torch torchvision torchaudio
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: torch in c:\users\dell\anaconda3\lib\site-packages (2.4.0)
# Collecting torchvision
#   Downloading torchvision-0.19.0-1-cp311-cp311-win_amd64.whl.metadata (6.1 kB)
# Collecting torchaudio
#   Downloading torchaudio-2.4.0-cp311-cp311-win_amd64.whl.metadata (6.4 kB)
# Requirement already satisfied: filelock in c:\users\dell\anaconda3\lib\site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\dell\anaconda3\lib\site-packages (from torch) (4.9.0)
# Requirement already satisfied: sympy in c:\users\dell\anaconda3\lib\site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in c:\users\dell\anaconda3\lib\site-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in c:\users\dell\anaconda3\lib\site-packages (from torch) (3.1.3)
# Requirement already satisfied: fsspec in c:\users\dell\anaconda3\lib\site-packages (from torch) (2023.10.0)
# Requirement already satisfied: numpy<2 in c:\users\dell\anaconda3\lib\site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\dell\anaconda3\lib\site-packages (from torchvision) (10.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\dell\anaconda3\lib\site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in c:\users\dell\anaconda3\lib\site-packages (from sympy->torch) (1.3.0)
# Downloading torchvision-0.19.0-1-cp311-cp311-win_amd64.whl (1.3 MB)
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#    - -------------------------------------- 0.0/1.3 MB 326.8 kB/s eta 0:00:04
#    -- ------------------------------------- 0.1/1.3 MB 573.4 kB/s eta 0:00:03
#    ---- ----------------------------------- 0.2/1.3 MB 833.5 kB/s eta 0:00:02
#    -------- ------------------------------- 0.3/1.3 MB 1.1 MB/s eta 0:00:01
#    ------------ --------------------------- 0.4/1.3 MB 1.2 MB/s eta 0:00:01
#    ----------------- ---------------------- 0.6/1.3 MB 1.5 MB/s eta 0:00:01
#    ------------------------- -------------- 0.8/1.3 MB 2.0 MB/s eta 0:00:01
#    -------------------------------------- - 1.2/1.3 MB 2.7 MB/s eta 0:00:01
#    ---------------------------------------- 1.3/1.3 MB 2.7 MB/s eta 0:00:00
# Downloading torchaudio-2.4.0-cp311-cp311-win_amd64.whl (2.4 MB)
#    ---------------------------------------- 0.0/2.4 MB ? eta -:--:--
#    ------------------- -------------------- 1.2/2.4 MB 38.3 MB/s eta 0:00:01
#    ------------------------------- -------- 1.9/2.4 MB 20.5 MB/s eta 0:00:01
#    ---------------------------------------- 2.4/2.4 MB 19.3 MB/s eta 0:00:00
# Installing collected packages: torchvision, torchaudio
# Successfully installed torchaudio-2.4.0 torchvision-0.19.0

# %%
tokenizer =  BertTokenizer.from_pretrained('bert-base-uncased')

encoded_essays

# %%
import pandas as pd

# %%
df_1 = pd.read_csv("datasets/df_with_features_set_1.csv")
df_1["overall_score"] = df_1["domain1_score"]
df_1
#domain1_score
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df_1 = pd.read_csv("datasets/df_with_features_set_1.csv")
#       2 df_1["overall_score"] = df_1["domain1_score"]
#       3 df_1
#
# File c:\Users\DELL\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\DELL\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#     614     return parser
#
# File c:\Users\DELL\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\DELL\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1705, in TextFileReader._make_engine(self, f, engine)
#    1703     if "b" not in mode:
#    1704         mode += "b"
# -> 1705 self.handles = get_handle(
#    1706     f,
#    1707     mode,
#    1708     encoding=self.options.get("encoding", None),
#    1709     compression=self.options.get("compression", None),
#    1710     memory_map=self.options.get("memory_map", False),
#    1711     is_text=is_text,
#    1712     errors=self.options.get("encoding_errors", "strict"),
#    1713     storage_options=self.options.get("storage_options", None),
#    1714 )
#    1715 assert self.handles is not None
#    1716 f = self.handles.handle
#
# File c:\Users\DELL\anaconda3\Lib\site-packages\pandas\io\common.py:863, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     858 elif isinstance(handle, str):
#     859     # Check whether the filename is to be opened in binary mode.
#     860     # Binary mode does not support 'encoding' and 'newline'.
#     861     if ioargs.encoding and "b" not in ioargs.mode:
#     862         # Encoding
# --> 863         handle = open(
#     864             handle,
#     865             ioargs.mode,
#     866             encoding=ioargs.encoding,
#     867             errors=errors,
#     868             newline="",
#     869         )
#     870     else:
#     871         # Binary mode
#     872         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'datasets/df_with_features_set_1.csv'

# %%
df_2 = pd.read_csv("datasets/df_with_features_set_2.csv")
df_2["overall_score"] = df_2["domain1_score"] + df_2["domain2_score"]
df_2
#domain1_score + domain2_score
# Out:
#       Unnamed: 0  essay_id  essay_set  \
# 0              0      2978          2
# 1              1      2979          2
# 2              2      2980          2
# 3              3      2981          2
# 4              4      2982          2
# ...          ...       ...        ...
# 1795        1795      4773          2
# 1796        1796      4774          2
# 1797        1797      4775          2
# 1798        1798      4776          2
# 1799        1799      4777          2
#
#                                                   essay  rater1_domain1  \
# 0     Certain materials being removed from libraries...             4.0
# 1     Write a persuasive essay to a newspaper reflec...             1.0
# 2     Do you think that libraries should remove cert...             2.0
# 3     In @DATE1's world, there are many things found...             4.0
# 4     In life you have the 'offensive things'. The l...             4.0
# ...                                                 ...             ...
# 1795  The author is writting about taking books off ...             3.0
# 1796  I do not think that materials, such as books, ...             3.0
# 1797  Yes we should keep the books,music,movies,an m...             2.0
# 1798  I do believe that  book, magazines, music, mov...             3.0
# 1799  Different Then Everyone Else     @CAPS1 do peo...             3.0
#
#       rater2_domain1  domain1_score  rater1_domain2  rater2_domain2  \
# 0                4.0            4.0             4.0             4.0
# 1                2.0            1.0             1.0             2.0
# 2                3.0            2.0             3.0             3.0
# 3                4.0            4.0             4.0             4.0
# 4                4.0            4.0             4.0             4.0
# ...              ...            ...             ...             ...
# 1795             2.0            3.0             3.0             2.0
# 1796             3.0            3.0             3.0             3.0
# 1797             2.0            2.0             2.0             2.0
# 1798             4.0            3.0             4.0             3.0
# 1799             3.0            3.0             2.0             3.0
#
#       domain2_score  ...  discourse_connective_count  vocabulary_richness  \
# 0               4.0  ...                           9             0.551111
# 1               1.0  ...                           5             0.671642
# 2               3.0  ...                           7             0.625000
# 3               4.0  ...                          10             0.517857
# 4               4.0  ...                           7             0.658986
# ...             ...  ...                         ...                  ...
# 1795            3.0  ...                           0             0.555556
# 1796            3.0  ...                           7             0.630631
# 1797            2.0  ...                           0             0.645161
# 1798            4.0  ...                          20             0.433476
# 1799            2.0  ...                          10             0.446078
#
#       semantic_relevance  flesch_reading_ease  flesch_kincaid_grade  \
# 0               0.835495                72.70                   9.0
# 1               0.799878                62.69                  15.0
# 2               0.919828                90.39                   4.3
# 3               0.841573                73.17                   6.8
# 4               0.809875                84.57                   4.5
# ...                  ...                  ...                   ...
# 1795            0.758942                85.12                   6.3
# 1796            0.870981                73.07                   6.8
# 1797            0.775418                82.38                   7.4
# 1798            0.795501                77.98                   7.0
# 1799            0.786998                78.59                   6.8
#
#       gunning_fog_index  smog_index  automated_readability_index  \
# 0                 10.19         9.5                         11.7
# 1                 18.23        11.7                         18.2
# 2                  7.15         8.2                          5.8
# 3                  7.29         9.9                          8.1
# 4                  5.88         7.9                          5.8
# ...                 ...         ...                          ...
# 1795               8.80         8.6                          9.3
# 1796               6.87         9.7                          7.4
# 1797               9.39         9.4                          9.7
# 1798               7.76         9.4                          8.4
# 1799               7.80         9.7                          7.3
#
#       coleman_liau_index  overall_score
# 0                   8.36            8.0
# 1                   6.17            2.0
# 2                   5.44            5.0
# 3                   8.52            8.0
# 4                   6.95            8.0
# ...                  ...            ...
# 1795                7.25            6.0
# 1796                7.42            6.0
# 1797                6.80            4.0
# 1798                7.31            7.0
# 1799                6.15            5.0
#
# [1800 rows x 27 columns]

# %%
df_3 = pd.read_csv("datasets/df_with_features_set_3.csv")
df_3.columns
df_3["overall_score"] = df_3["domain1_score"]
df_3
#domain_1_score
# Out:
#       Unnamed: 0  essay_id  essay_set  \
# 0              0      5978          3
# 1              1      5979          3
# 2              2      5980          3
# 3              3      5981          3
# 4              4      5982          3
# ...          ...       ...        ...
# 1721        1721      7704          3
# 1722        1722      7705          3
# 1723        1723      7706          3
# 1724        1724      7707          3
# 1725        1725      7708          3
#
#                                                   essay  rater1_domain1  \
# 0     The features of the setting affect the cyclist...             1.0
# 1     The features of the setting affected the cycli...             2.0
# 2     Everyone travels to unfamiliar places. Sometim...             1.0
# 3     I believe the features of the cyclist affected...             1.0
# 4     The setting effects the cyclist because of the...             2.0
# ...                                                 ...             ...
# 1721  In the story, the setting affected the cyclist...             2.0
# 1722  The features of the setting affect the cyclist...             1.0
# 1723  The setting greatly affects the cyclist trying...             1.0
# 1724  The features of the setting affected the cycli...             2.0
# 1725  The features of the setting in “Rough Road Ahe...             2.0
#
#       rater2_domain1  domain1_score  num_grammatical_errors  \
# 0                1.0            1.0                       1
# 1                2.0            2.0                      20
# 2                1.0            1.0                       1
# 3                1.0            1.0                      13
# 4                2.0            2.0                      11
# ...              ...            ...                     ...
# 1721             2.0            2.0                       1
# 1722             1.0            1.0                       2
# 1723             2.0            2.0                       3
# 1724             2.0            2.0                       1
# 1725             3.0            3.0                       1
#
#       adjacent_sentence_similarity  lexical_repetition_ratio  ...  \
# 0                         0.753816                  0.526316  ...
# 1                         0.609883                  0.324324  ...
# 2                         0.603322                  0.441860  ...
# 3                         0.652176                  0.105263  ...
# 4                         0.717675                  0.442308  ...
# ...                            ...                       ...  ...
# 1721                      0.635071                  0.200000  ...
# 1722                      0.682107                  0.137931  ...
# 1723                      0.728421                  0.260870  ...
# 1724                      0.715650                  0.508197  ...
# 1725                      0.716121                  0.222222  ...
#
#       discourse_connective_count  vocabulary_richness  semantic_relevance  \
# 0                              1             0.714286            0.793871
# 1                              2             0.823529            0.737808
# 2                              3             0.851064            0.772385
# 3                              3             0.975610            0.650273
# 4                              4             0.704918            0.687995
# ...                          ...                  ...                 ...
# 1721                           0             0.916667            0.729866
# 1722                           3             0.935484            0.771711
# 1723                           3             0.851852            0.747044
# 1724                           5             0.760563            0.769162
# 1725                           4             0.898305            0.782818
#
#       flesch_reading_ease  flesch_kincaid_grade  gunning_fog_index  \
# 0                   71.14                   7.6               8.37
# 1                   70.63                   7.8               9.74
# 2                   83.05                   5.1               7.55
# 3                   67.72                  10.9              13.81
# 4                   63.06                  12.7              13.62
# ...                   ...                   ...                ...
# 1721                85.69                   4.0               6.82
# 1722                78.59                   6.8               9.42
# 1723                69.62                   8.1               9.20
# 1724                66.67                   9.3              10.43
# 1725                64.44                  10.1              11.81
#
#       smog_index  automated_readability_index  coleman_liau_index  \
# 0            7.8                          6.7                6.20
# 1           11.0                          9.9                8.64
# 2            9.2                          6.0                6.78
# 3           10.5                         11.8                6.16
# 4            8.1                         15.4                7.44
# ...          ...                          ...                 ...
# 1721         7.8                          4.6                5.55
# 1722         8.8                          8.6                7.54
# 1723         9.7                          8.5                7.25
# 1724        10.0                         10.6                8.01
# 1725        10.8                         11.3                8.01
#
#       overall_score
# 0               1.0
# 1               2.0
# 2               1.0
# 3               1.0
# 4               2.0
# ...             ...
# 1721            2.0
# 1722            1.0
# 1723            2.0
# 1724            2.0
# 1725            3.0
#
# [1726 rows x 24 columns]

# %%
df_4 = pd.read_csv("datasets/df_with_features_set_4.csv")
df_4["overall_score"] = df_4["domain1_score"]
df_4
#domain_1_score
# Out:
#       Unnamed: 0  essay_id  essay_set  \
# 0              0      8863          4
# 1              1      8864          4
# 2              2      8865          4
# 3              3      8866          4
# 4              4      8867          4
# ...          ...       ...        ...
# 1767        1767     10638          4
# 1768        1768     10639          4
# 1769        1769     10640          4
# 1770        1770     10641          4
# 1771        1771     10642          4
#
#                                                   essay  rater1_domain1  \
# 0     The author concludes the story with this becau...             0.0
# 1     The narrater has that in with Paragraph becuse...             0.0
# 2     The author concludes the story with that passa...             3.0
# 3     The author ended the story with this paragraph...             1.0
# 4     The author concludes the story with this parag...             2.0
# ...                                                 ...             ...
# 1767  To me it seam like the whoever was saying that...             0.0
# 1768  The author concludes the story with this becau...             2.0
# 1769  The author uses this conclusion for a reason. ...             1.0
# 1770  The author concludes the story with this parag...             0.0
# 1771  There was a specific reason as to why the auth...             1.0
#
#       rater2_domain1  domain1_score  num_grammatical_errors  \
# 0                0.0            0.0                       5
# 1                0.0            0.0                      12
# 2                2.0            3.0                       4
# 3                2.0            2.0                       1
# 4                2.0            2.0                       5
# ...              ...            ...                     ...
# 1767             0.0            0.0                       7
# 1768             2.0            2.0                       2
# 1769             1.0            1.0                       4
# 1770             0.0            0.0                       3
# 1771             2.0            2.0                       2
#
#       adjacent_sentence_similarity  lexical_repetition_ratio  ...  \
# 0                         0.731869                  0.304348  ...
# 1                         0.836288                  0.235294  ...
# 2                         0.802539                  0.671875  ...
# 3                         0.635773                  0.303030  ...
# 4                         0.631637                  0.460000  ...
# ...                            ...                       ...  ...
# 1767                      0.803263                  0.592593  ...
# 1768                      0.662211                  0.291667  ...
# 1769                      0.740102                  0.576923  ...
# 1770                      0.712796                  0.235294  ...
# 1771                      0.704453                  0.281250  ...
#
#       discourse_connective_count  vocabulary_richness  semantic_relevance  \
# 0                              4             0.833333            0.814942
# 1                              1             0.882353            0.697761
# 2                              2             0.606061            0.872773
# 3                              2             0.823529            0.859708
# 4                              3             0.745763            0.875682
# ...                          ...                  ...                 ...
# 1767                           4             0.843750            0.691067
# 1768                           4             0.818182            0.806496
# 1769                           1             0.666667            0.845734
# 1770                           2             1.000000            0.848951
# 1771                           0             0.857143            0.841112
#
#       flesch_reading_ease  flesch_kincaid_grade  gunning_fog_index  \
# 0                   69.41                   8.2               8.91
# 1                   77.06                   7.4               8.83
# 2                   52.33                  12.7              13.53
# 3                   77.43                   5.1               6.78
# 4                   82.44                   5.3               7.24
# ...                   ...                   ...                ...
# 1767                55.24                  15.7              16.89
# 1768                89.48                   4.7               7.78
# 1769                69.11                   8.3               8.30
# 1770                69.62                   8.1               8.48
# 1771                81.63                   5.6               9.20
#
#       smog_index  automated_readability_index  coleman_liau_index  \
# 0           10.5                          8.8                7.89
# 1            0.0                          8.7                7.54
# 2           13.7                         14.9               10.45
# 3            8.8                          6.8                9.03
# 4            8.2                          7.0                7.59
# ...          ...                          ...                 ...
# 1767         0.0                         19.3                7.85
# 1768         7.6                          5.7                5.80
# 1769         8.8                          9.9                8.59
# 1770         0.0                          9.9                9.34
# 1771         9.4                          6.2                6.49
#
#       overall_score
# 0               0.0
# 1               0.0
# 2               3.0
# 3               2.0
# 4               2.0
# ...             ...
# 1767            0.0
# 1768            2.0
# 1769            1.0
# 1770            0.0
# 1771            2.0
#
# [1772 rows x 24 columns]

# %%
df_5= pd.read_csv("datasets/df_with_features_set_5.csv")
df_5["overall_score"] = df_5["domain1_score"]
df_5
#domain_1_score
# Out:
#       Unnamed: 0  essay_id  essay_set  \
# 0              0     11827          5
# 1              1     11828          5
# 2              2     11829          5
# 3              3     11830          5
# 4              4     11831          5
# ...          ...       ...        ...
# 1800        1800     13627          5
# 1801        1801     13628          5
# 1802        1802     13629          5
# 1803        1803     13630          5
# 1804        1804     13631          5
#
#                                                   essay  rater1_domain1  \
# 0     In this memoir of Narciso Rodriguez, @PERSON3'...             2.0
# 1     Throughout the excerpt from Home the Blueprint...             2.0
# 2     The mood the author created in the memoir is l...             3.0
# 3     The mood created by the author is showing how ...             1.0
# 4     The mood created in the memoir is happiness an...             2.0
# ...                                                 ...             ...
# 1800  The mood of this memoir is nonfiction. The moo...             2.0
# 1801  The mood was created by the author in the memo...             0.0
# 1802  In the memoir "Narciso Rodriguez", the mood cr...             3.0
# 1803  The mood created @CAPS3 the author, Narciso Ro...             3.0
# 1804  The author created such a specific mood for th...             2.0
#
#       rater2_domain1  domain1_score  num_grammatical_errors  \
# 0                2.0            2.0                       6
# 1                2.0            2.0                       5
# 2                3.0            3.0                       6
# 3                0.0            1.0                      11
# 4                3.0            3.0                       6
# ...              ...            ...                     ...
# 1800             1.0            2.0                       4
# 1801             0.0            0.0                       2
# 1802             4.0            4.0                      13
# 1803             2.0            3.0                       4
# 1804             2.0            2.0                       6
#
#       adjacent_sentence_similarity  lexical_repetition_ratio  ...  \
# 0                         0.643429                  0.433333  ...
# 1                         0.730897                  0.365079  ...
# 2                         0.772561                  0.346154  ...
# 3                         0.538054                  0.535714  ...
# 4                         0.719700                  0.306122  ...
# ...                            ...                       ...  ...
# 1800                      0.710747                  0.466667  ...
# 1801                      0.000000                  0.416667  ...
# 1802                      0.656544                  0.527027  ...
# 1803                      0.744772                  0.448276  ...
# 1804                      0.691502                  0.179487  ...
#
#       discourse_connective_count  vocabulary_richness  semantic_relevance  \
# 0                              2             0.767857            0.727040
# 1                              4             0.822785            0.738815
# 2                              2             0.826923            0.704115
# 3                              0             0.678571            0.670613
# 4                              2             0.796296            0.679905
# ...                          ...                  ...                 ...
# 1800                           5             0.711864            0.747313
# 1801                           0             0.818182            0.725839
# 1802                           2             0.738095            0.706081
# 1803                           1             0.818182            0.753941
# 1804                           1             0.875000            0.734831
#
#       flesch_reading_ease  flesch_kincaid_grade  gunning_fog_index  \
# 0                   77.67                   7.1               9.38
# 1                   72.60                   9.1              11.00
# 2                   69.92                   8.0               9.11
# 3                   72.80                   9.0              10.04
# 4                   72.26                   7.1               8.88
# ...                   ...                   ...                ...
# 1800                69.72                   8.1               8.60
# 1801                67.42                  11.1              14.36
# 1802                69.72                   8.1               8.56
# 1803                66.07                   9.5              10.62
# 1804                72.46                   7.1               9.68
#
#       smog_index  automated_readability_index  coleman_liau_index  \
# 0            9.2                         10.0                8.36
# 1            9.2                         11.4                8.01
# 2            9.7                         11.2                9.74
# 3            7.8                         12.0                8.88
# 4           10.1                          7.2                7.25
# ...          ...                          ...                 ...
# 1800        10.0                         10.0                8.82
# 1801         0.0                         13.4                7.50
# 1802         9.7                          9.4                8.36
# 1803         9.3                         11.7                8.76
# 1804        10.9                          7.5                7.77
#
#       overall_score
# 0               2.0
# 1               2.0
# 2               3.0
# 3               1.0
# 4               3.0
# ...             ...
# 1800            2.0
# 1801            0.0
# 1802            4.0
# 1803            3.0
# 1804            2.0
#
# [1805 rows x 24 columns]

# %%
df_6 = pd.read_csv("datasets/df_with_features_set_6_2.csv")
df_6["overall_score"] = df_6["domain1_score"]
df_6
#domain_1_score
# Out:
#       Unnamed: 0  essay_id  essay_set  \
# 0              0     14834          6
# 1              1     14835          6
# 2              2     14836          6
# 3              3     14837          6
# 4              4     14838          6
# ...          ...       ...        ...
# 1795        1795     16629          6
# 1796        1796     16630          6
# 1797        1797     16631          6
# 1798        1798     16632          6
# 1799        1799     16633          6
#
#                                                   essay  rater1_domain1  \
# 0     There were many obstacles that the builders fa...             2.0
# 1     Him from the start, there would have been many...             3.0
# 2     The builders of the Empire State Building face...             3.0
# 3     In the passage The Mooring Mast by Marcia Amid...             1.0
# 4     The builders of the Empire State Building face...             3.0
# ...                                                 ...             ...
# 1795  The one obstacle the builders had when trying ...             2.0
# 1796  Some of the problems with the constructing of ...             1.0
# 1797  The builders of the Empire State building face...             2.0
# 1798  The obstacles the builders of the Empire State...             2.0
# 1799  You want me to tell you what they had to go th...             2.0
#
#       rater2_domain1  domain1_score  num_grammatical_errors  \
# 0                2.0            2.0                       3
# 1                3.0            3.0                       2
# 2                4.0            4.0                       2
# 3                1.0            1.0                      11
# 4                3.0            3.0                       1
# ...              ...            ...                     ...
# 1795             0.0            0.0                      11
# 1796             2.0            2.0                       1
# 1797             3.0            3.0                       3
# 1798             1.0            2.0                       2
# 1799             2.0            2.0                       7
#
#       adjacent_sentence_similarity  lexical_repetition_ratio  ...  \
# 0                         0.658530                  0.211538  ...
# 1                         0.666931                  0.407895  ...
# 2                         0.712244                  0.438356  ...
# 3                         0.683533                  0.425532  ...
# 4                         0.691238                  0.513158  ...
# ...                            ...                       ...  ...
# 1795                      0.700723                  0.446154  ...
# 1796                      0.672424                  0.156250  ...
# 1797                      0.743890                  0.382979  ...
# 1798                      0.782740                  0.400000  ...
# 1799                      0.619621                  0.587302  ...
#
#       discourse_connective_count  vocabulary_richness  semantic_relevance  \
# 0                              3             0.868852            0.786340
# 1                              3             0.804598            0.824759
# 2                              3             0.758242            0.817259
# 3                              5             0.676768            0.778473
# 4                              2             0.691489            0.815284
# ...                          ...                  ...                 ...
# 1795                           6             0.753425            0.757160
# 1796                           2             0.923077            0.740194
# 1797                           2             0.814815            0.790243
# 1798                           2             0.837838            0.788797
# 1799                           4             0.641026            0.765174
#
#       flesch_reading_ease  flesch_kincaid_grade  gunning_fog_index  \
# 0                   59.33                  10.0              10.74
# 1                   68.10                   8.7              10.89
# 2                   67.28                   9.0              10.97
# 3                   68.81                   8.5               9.17
# 4                   63.49                   8.4               9.44
# ...                   ...                   ...                ...
# 1795                79.50                   6.4               8.66
# 1796                57.61                  10.7              11.83
# 1797                58.62                  10.3              11.45
# 1798                53.89                  14.2              15.95
# 1799                76.76                   7.5               8.93
#
#       smog_index  automated_readability_index  coleman_liau_index  \
# 0           11.5                         10.9                9.40
# 1           11.0                         11.4               10.15
# 2           11.0                         10.9                9.23
# 3            9.6                         10.3                9.11
# 4           11.6                          9.0                9.39
# ...          ...                          ...                 ...
# 1795         9.2                          8.8                8.35
# 1796        13.0                         12.7               10.73
# 1797        12.3                         11.6                9.75
# 1798         0.0                         16.9                9.35
# 1799        10.4                          8.7                6.96
#
#       overall_score
# 0               2.0
# 1               3.0
# 2               4.0
# 3               1.0
# 4               3.0
# ...             ...
# 1795            0.0
# 1796            2.0
# 1797            3.0
# 1798            2.0
# 1799            2.0
#
# [1800 rows x 24 columns]

# %%
df_7 = pd.read_csv("datasets/df_with_features_set_7_2.csv")
df_7["overall_score"] = df_7["domain1_score"]
df_7
#domain_1_score
# Out:
#       Unnamed: 0.1  Unnamed: 0  essay_id  essay_set  \
# 0                0           0     17834          7
# 1                1           1     17836          7
# 2                2           2     17837          7
# 3                3           3     17838          7
# 4                4           4     17839          7
# ...            ...         ...       ...        ...
# 1564          1564        1564     19558          7
# 1565          1565        1565     19559          7
# 1566          1566        1566     19561          7
# 1567          1567        1567     19562          7
# 1568          1568        1568     19563          7
#
#                                                   essay  rater1_domain1  \
# 0     Patience is when your waiting .I was patience ...             8.0
# 1     I am not a patience person, like I can’t sit i...             6.0
# 2     One day I was at basketball practice and I was...             7.0
# 3     I going to write about a time when I went to t...             8.0
# 4     It can be very hard for somebody to be patient...             7.0
# ...                                                 ...             ...
# 1564  One time I was getting a cool @CAPS1 game it w...             6.0
# 1565  A patent person in my life is my mom. Aicason ...             9.0
# 1566  A time when someone else I know was patient wa...            11.0
# 1567  I hate weddings. I love when people get marrie...            12.0
# 1568  A few weeks ago, we had a garage sale and a mo...             7.0
#
#       rater2_domain1  domain1_score  rater1_trait1  rater1_trait2  ...  \
# 0                7.0           15.0            1.0            2.0  ...
# 1                7.0           13.0            1.0            1.0  ...
# 2                8.0           15.0            1.0            2.0  ...
# 3                9.0           17.0            2.0            2.0  ...
# 4                6.0           13.0            1.0            2.0  ...
# ...              ...            ...            ...            ...  ...
# 1564             6.0           12.0            2.0            2.0  ...
# 1565             7.0           16.0            2.0            2.0  ...
# 1566             8.0           19.0            3.0            3.0  ...
# 1567            10.0           22.0            3.0            3.0  ...
# 1568             8.0           15.0            2.0            1.0  ...
#
#       discourse_connective_count  vocabulary_richness  semantic_relevance  \
# 0                              5             0.647059            0.817931
# 1                              2             0.738095            0.733223
# 2                              7             0.764706            0.740397
# 3                              9             0.771739            0.836043
# 4                             11             0.596774            0.850627
# ...                          ...                  ...                 ...
# 1564                           0             0.875000            0.687756
# 1565                          12             0.752212            0.779246
# 1566                           5             0.777778            0.806946
# 1567                           8             0.794393            0.694650
# 1568                           3             0.609375            0.771673
#
#       flesch_reading_ease  flesch_kincaid_grade  gunning_fog_index  \
# 0                   88.53                   2.9               3.28
# 1                   73.55                  10.8              12.95
# 2                   66.44                  13.5              15.84
# 3                   88.36                   5.1               7.60
# 4                   84.07                   4.7               5.83
# ...                   ...                   ...                ...
# 1564               103.52                   1.3               4.04
# 1565                71.68                   9.4              11.89
# 1566                83.86                   4.7               6.32
# 1567                87.62                   3.3               5.16
# 1568                94.90                   4.6               7.44
#
#       smog_index  automated_readability_index  coleman_liau_index  \
# 0            4.9                          3.5                5.24
# 1            8.8                         12.5                5.29
# 2           10.7                         16.5                5.87
# 3            7.3                          6.6                5.33
# 4            7.5                          5.4                6.13
# ...          ...                          ...                 ...
# 1564         3.1                          0.1                0.79
# 1565        10.3                         11.0                7.32
# 1566         8.4                          4.8                5.44
# 1567         7.2                          4.2                4.32
# 1568         3.1                          4.0                2.09
#
#       overall_score
# 0              15.0
# 1              13.0
# 2              15.0
# 3              17.0
# 4              13.0
# ...             ...
# 1564           12.0
# 1565           16.0
# 1566           19.0
# 1567           22.0
# 1568           15.0
#
# [1569 rows x 33 columns]

# %%
df_8 = pd.read_csv("datasets/df_with_features_set_8.csv")
df_8["overall_score"] = df_8["domain1_score"]
df_8
#domain_1_score
# Out:
#      Unnamed: 0  essay_id  essay_set  \
# 0             0     20716          8
# 1             1     20717          8
# 2             2     20718          8
# 3             3     20719          8
# 4             4     20721          8
# ..          ...       ...        ...
# 718         718     21626          8
# 719         719     21628          8
# 720         720     21629          8
# 721         721     21630          8
# 722         722     21633          8
#
#                                                  essay  rater1_domain1  \
# 0     A long time ago when I was in third grade I h...            18.0
# 1     Softball has to be one of the single most gre...            21.0
# 2     Some people like making people laugh, I love ...            15.0
# 3     "LAUGHTER"  @CAPS1 I hang out with my friends...            12.0
# 4    Well ima tell a story about the time i got @CA...            11.0
# ..                                                 ...             ...
# 718   In most stories mothers and daughters are eit...            17.0
# 719   I never understood the meaning laughter is th...            15.0
# 720  When you laugh, is @CAPS5 out of habit, or is ...            20.0
# 721                                 Trippin' on fen...            20.0
# 722   Many people believe that laughter can improve...            20.0
#
#      rater2_domain1  domain1_score  rater1_trait1  rater1_trait2  \
# 0              16.0           34.0            4.0            4.0
# 1              26.0           46.0            5.0            4.0
# 2              20.0           40.0            3.0            3.0
# 3              20.0           30.0            3.0            3.0
# 4              15.0           26.0            3.0            2.0
# ..              ...            ...            ...            ...
# 718            18.0           35.0            4.0            3.0
# 719            17.0           32.0            3.0            3.0
# 720            26.0           40.0            4.0            4.0
# 721            20.0           40.0            4.0            4.0
# 722            20.0           40.0            4.0            4.0
#
#      rater1_trait3  ...  discourse_connective_count  vocabulary_richness  \
# 0              4.0  ...                          13             0.520505
# 1              5.0  ...                          16             0.635593
# 2              3.0  ...                          16             0.578164
# 3              3.0  ...                          14             0.595070
# 4              3.0  ...                          17             0.522388
# ..             ...  ...                         ...                  ...
# 718            4.0  ...                          19             0.627072
# 719            4.0  ...                           7             0.550000
# 720            4.0  ...                          17             0.745509
# 721            4.0  ...                          21             0.663793
# 722            4.0  ...                           9             0.707547
#
#      semantic_relevance  flesch_reading_ease  flesch_kincaid_grade  \
# 0              0.707057                88.87                   4.9
# 1              0.777121                78.93                   8.7
# 2              0.795551                74.83                   8.2
# 3              0.737897                81.46                   7.7
# 4              0.625690                88.60                   7.1
# ..                  ...                  ...                   ...
# 718            0.794858                65.09                  12.0
# 719            0.791210                91.11                   4.0
# 720            0.766729                69.11                   8.3
# 721            0.819285                81.83                   5.5
# 722            0.863376                72.05                   7.2
#
#      gunning_fog_index  smog_index  automated_readability_index  \
# 0                 6.90         7.0                          6.1
# 1                11.37         8.9                         10.8
# 2                 9.62         8.5                          9.1
# 3                 9.68         7.0                          8.3
# 4                 9.98         4.2                          7.7
# ..                 ...         ...                          ...
# 718              13.56        10.3                         14.4
# 719               5.97         7.1                          5.1
# 720               9.46         9.7                          9.9
# 721               7.41         8.5                          6.8
# 722               8.67         9.9                          7.4
#
#      coleman_liau_index  overall_score
# 0                  5.10           34.0
# 1                  6.04           46.0
# 2                  6.15           40.0
# 3                  4.65           30.0
# 4                  3.08           26.0
# ..                  ...            ...
# 718                7.03           35.0
# 719                4.98           32.0
# 720                8.18           40.0
# 721                6.55           40.0
# 722                7.07           40.0
#
# [723 rows x 36 columns]

# %%
df_11 = df_1[['essay_id','essay_set', 'essay',
       'num_grammatical_errors',
       'lexical_repetition_ratio', 'unique_lemmas_count',
       'avg_sentence_length',
       'discourse_connective_count', 'vocabulary_richness',
       'semantic_relevance', 'flesch_reading_ease', 'flesch_kincaid_grade',
       'overall_score']]
df_11.columns
# Out:
# Index(['essay_id', 'essay_set', 'essay', 'num_grammatical_errors',
#        'lexical_repetition_ratio', 'unique_lemmas_count',
#        'avg_sentence_length', 'discourse_connective_count',
#        'vocabulary_richness', 'semantic_relevance', 'flesch_reading_ease',
#        'flesch_kincaid_grade', 'overall_score'],
#       dtype='object')

# %%
df_22 = df_2[['essay_id','essay_set', 'essay',
       'num_grammatical_errors',
       'lexical_repetition_ratio', 'unique_lemmas_count',
       'avg_sentence_length',
       'discourse_connective_count', 'vocabulary_richness',
       'semantic_relevance', 'flesch_reading_ease', 'flesch_kincaid_grade',
       'overall_score']]
df_22.columns
# Out:
# Index(['essay_id', 'essay_set', 'essay', 'num_grammatical_errors',
#        'lexical_repetition_ratio', 'unique_lemmas_count',
#        'avg_sentence_length', 'discourse_connective_count',
#        'vocabulary_richness', 'semantic_relevance', 'flesch_reading_ease',
#        'flesch_kincaid_grade', 'overall_score'],
#       dtype='object')

# %%
df_33 = df_3[['essay_id','essay_set', 'essay',
       'num_grammatical_errors',
       'lexical_repetition_ratio', 'unique_lemmas_count',
       'avg_sentence_length',
       'discourse_connective_count', 'vocabulary_richness',
       'semantic_relevance', 'flesch_reading_ease', 'flesch_kincaid_grade',
       'overall_score']]
df_33.columns
# Out:
# Index(['essay_id', 'essay_set', 'essay', 'num_grammatical_errors',
#        'lexical_repetition_ratio', 'unique_lemmas_count',
#        'avg_sentence_length', 'discourse_connective_count',
#        'vocabulary_richness', 'semantic_relevance', 'flesch_reading_ease',
#        'flesch_kincaid_grade', 'overall_score'],
#       dtype='object')

# %%
df_44 = df_4[['essay_id','essay_set', 'essay',
       'num_grammatical_errors',
       'lexical_repetition_ratio', 'unique_lemmas_count',
       'avg_sentence_length',
       'discourse_connective_count', 'vocabulary_richness',
       'semantic_relevance', 'flesch_reading_ease', 'flesch_kincaid_grade',
       'overall_score']]
df_44.columns
# Out:
# Index(['essay_id', 'essay_set', 'essay', 'num_grammatical_errors',
#        'lexical_repetition_ratio', 'unique_lemmas_count',
#        'avg_sentence_length', 'discourse_connective_count',
#        'vocabulary_richness', 'semantic_relevance', 'flesch_reading_ease',
#        'flesch_kincaid_grade', 'overall_score'],
#       dtype='object')

# %%
df_55 = df_5[['essay_id','essay_set', 'essay',
       'num_grammatical_errors',
       'lexical_repetition_ratio', 'unique_lemmas_count',
       'avg_sentence_length',
       'discourse_connective_count', 'vocabulary_richness',
       'semantic_relevance', 'flesch_reading_ease', 'flesch_kincaid_grade',
       'overall_score']]
df_55.columns
# Out:
# Index(['essay_id', 'essay_set', 'essay', 'num_grammatical_errors',
#        'lexical_repetition_ratio', 'unique_lemmas_count',
#        'avg_sentence_length', 'discourse_connective_count',
#        'vocabulary_richness', 'semantic_relevance', 'flesch_reading_ease',
#        'flesch_kincaid_grade', 'overall_score'],
#       dtype='object')

# %%
df_66 = df_6[['essay_id','essay_set', 'essay',
       'num_grammatical_errors',
       'lexical_repetition_ratio', 'unique_lemmas_count',
       'avg_sentence_length',
       'discourse_connective_count', 'vocabulary_richness',
       'semantic_relevance', 'flesch_reading_ease', 'flesch_kincaid_grade',
       'overall_score']]
df_66.columns
# Out:
# Index(['essay_id', 'essay_set', 'essay', 'num_grammatical_errors',
#        'lexical_repetition_ratio', 'unique_lemmas_count',
#        'avg_sentence_length', 'discourse_connective_count',
#        'vocabulary_richness', 'semantic_relevance', 'flesch_reading_ease',
#        'flesch_kincaid_grade', 'overall_score'],
#       dtype='object')

# %%
df_77 = df_7[['essay_id','essay_set', 'essay',
       'num_grammatical_errors',
       'lexical_repetition_ratio', 'unique_lemmas_count',
       'avg_sentence_length',
       'discourse_connective_count', 'vocabulary_richness',
       'semantic_relevance', 'flesch_reading_ease', 'flesch_kincaid_grade',
       'overall_score']]
df_77.columns
# Out:
# Index(['essay_id', 'essay_set', 'essay', 'num_grammatical_errors',
#        'lexical_repetition_ratio', 'unique_lemmas_count',
#        'avg_sentence_length', 'discourse_connective_count',
#        'vocabulary_richness', 'semantic_relevance', 'flesch_reading_ease',
#        'flesch_kincaid_grade', 'overall_score'],
#       dtype='object')

# %%
df_88 = df_8[['essay_id','essay_set', 'essay',
       'num_grammatical_errors',
       'lexical_repetition_ratio', 'unique_lemmas_count',
       'avg_sentence_length',
       'discourse_connective_count', 'vocabulary_richness',
       'semantic_relevance', 'flesch_reading_ease', 'flesch_kincaid_grade',
       'overall_score']]
df_88
# Out:
#      essay_id  essay_set                                              essay  \
# 0       20716          8   A long time ago when I was in third grade I h...
# 1       20717          8   Softball has to be one of the single most gre...
# 2       20718          8   Some people like making people laugh, I love ...
# 3       20719          8   "LAUGHTER"  @CAPS1 I hang out with my friends...
# 4       20721          8  Well ima tell a story about the time i got @CA...
# ..        ...        ...                                                ...
# 718     21626          8   In most stories mothers and daughters are eit...
# 719     21628          8   I never understood the meaning laughter is th...
# 720     21629          8  When you laugh, is @CAPS5 out of habit, or is ...
# 721     21630          8                                 Trippin' on fen...
# 722     21633          8   Many people believe that laughter can improve...
#
#      num_grammatical_errors  lexical_repetition_ratio  unique_lemmas_count  \
# 0                        61                  0.680272                  148
# 1                        17                  0.633898                  163
# 2                        21                  0.611446                  178
# 3                        70                  0.674699                  134
# 4                       115                  0.751825                  111
# ..                      ...                       ...                  ...
# 718                      19                  0.575472                  188
# 719                      44                  0.701357                  110
# 720                      14                  0.537143                  220
# 721                       6                  0.574766                  127
# 722                       2                  0.527638                  125
#
#      avg_sentence_length  discourse_connective_count  vocabulary_richness  \
# 0              16.954545                          13             0.520505
# 1              23.916667                          16             0.635593
# 2              23.142857                          16             0.578164
# 3              19.973684                          14             0.595070
# 4              13.018519                          17             0.522388
# ..                   ...                         ...                  ...
# 718            23.243902                          19             0.627072
# 719            16.282051                           7             0.550000
# 720            21.222222                          17             0.745509
# 721            17.076923                          21             0.663793
# 722            18.310345                           9             0.707547
#
#      semantic_relevance  flesch_reading_ease  flesch_kincaid_grade  \
# 0              0.707057                88.87                   4.9
# 1              0.777121                78.93                   8.7
# 2              0.795551                74.83                   8.2
# 3              0.737897                81.46                   7.7
# 4              0.625690                88.60                   7.1
# ..                  ...                  ...                   ...
# 718            0.794858                65.09                  12.0
# 719            0.791210                91.11                   4.0
# 720            0.766729                69.11                   8.3
# 721            0.819285                81.83                   5.5
# 722            0.863376                72.05                   7.2
#
#      overall_score
# 0             34.0
# 1             46.0
# 2             40.0
# 3             30.0
# 4             26.0
# ..             ...
# 718           35.0
# 719           32.0
# 720           40.0
# 721           40.0
# 722           40.0
#
# [723 rows x 13 columns]

# %%
df_88.isna().sum()
# Out:
# essay_id                      0
# essay_set                     0
# essay                         0
# num_grammatical_errors        0
# lexical_repetition_ratio      0
# unique_lemmas_count           0
# avg_sentence_length           0
# discourse_connective_count    0
# vocabulary_richness           0
# semantic_relevance            0
# flesch_reading_ease           0
# flesch_kincaid_grade          0
# overall_score                 0
# dtype: int64

# %%
df_88.head(3)
# Out:
#    essay_set                                              essay  \
# 0          8   A long time ago when I was in third grade I h...
# 1          8   Softball has to be one of the single most gre...
# 2          8   Some people like making people laugh, I love ...
#
#    num_grammatical_errors  adjacent_sentence_similarity  \
# 0                      61                      0.674467
# 1                      17                      0.703512
# 2                      21                      0.707248
#
#    lexical_repetition_ratio  unique_lemmas_count  pronoun_count  \
# 0                  0.680272                  148            140
# 1                  0.633898                  163            133
# 2                  0.611446                  178            142
#
#    avg_sentence_length  sentence_length_std  discourse_connective_count  \
# 0            16.954545             9.002410                          13
# 1            23.916667            11.949837                          16
# 2            23.142857            11.317015                          16
#
#    vocabulary_richness  semantic_relevance  flesch_reading_ease  \
# 0             0.520505            0.707057                88.87
# 1             0.635593            0.777121                78.93
# 2             0.578164            0.795551                74.83
#
#    flesch_kincaid_grade  gunning_fog_index  smog_index  \
# 0                   4.9               6.90         7.0
# 1                   8.7              11.37         8.9
# 2                   8.2               9.62         8.5
#
#    automated_readability_index  coleman_liau_index  overall_score
# 0                          6.1                5.10           34.0
# 1                         10.8                6.04           46.0
# 2                          9.1                6.15           40.0

# %%
import pandas as pd

def min_max_scaling_column(df, min_value, max_value):    
    if max_value != min_value:  # Avoid division by zero
        df["scaled_score"] = (df["overall_score"] - min_value) / (max_value - min_value)
    else:
        df["scaled_score"] = 0  # If all values are the same, scale to 0
    
    return df


score_ranges = {
    1: (2, 12),  # Essay Set 1
    2: (2, 10),  # Essay Set 2
    3: (0, 3),   # Essay Set 3
    4: (0, 3),   # Essay Set 4
    5: (0, 4),   # Essay Set 5
    6: (0, 4),   # Essay Set 6
    7: (0, 30),  # Essay Set 7
    8: (0, 60)   # Essay Set 8
}

def inverse_min_max_scaling(predicted_val, essay_set):
    if essay_set in score_ranges:
        min_value, max_value = score_ranges[essay_set]
        
        if max_value != min_value:  # Avoid division by zero
            scale_up_predicted = predicted_val* (max_value - min_value) + min_value
        else:
            scale_up_predicted = min_value  # If all values were the same, original value is min_value
    else:
        raise ValueError(f"Invalid essay set number: {essay_set}")
    
    return scale_up_predicted

# %%
df_c1 = df_11
df_c1
# Out:
#       essay_id  essay_set                                              essay  \
# 0            1          1  Dear local newspaper, I think effects computer...
# 1            2          1  Dear @CAPS1 @CAPS2, I believe that using compu...
# 2            3          1  Dear, @CAPS1 @CAPS2 @CAPS3 More and more peopl...
# 3            4          1  Dear Local Newspaper, @CAPS1 I have found that...
# 4            5          1  Dear @LOCATION1, I know having computers has a...
# ...        ...        ...                                                ...
# 1778      1783          1  Dear @CAPS1, @CAPS2 several reasons on way I t...
# 1779      1784          1  Do a adults and kids spend to much time on the...
# 1780      1785          1  My opinion is that people should have computer...
# 1781      1786          1  Dear readers, I think that its good and bad to...
# 1782      1787          1  Dear - Local Newspaper I agree thats computers...
#
#       num_grammatical_errors  lexical_repetition_ratio  unique_lemmas_count  \
# 0                         17                  0.523810                   95
# 1                         24                  0.606557                  105
# 2                         14                  0.508333                   75
# 3                         29                  0.600000                  155
# 4                         18                  0.631285                  102
# ...                      ...                       ...                  ...
# 1778                      32                  0.632353                  114
# 1779                      15                  0.565789                   49
# 1780                      14                  0.772358                   46
# 1781                       0                  0.000000                    7
# 1782                      19                  0.395349                   61
#
#       avg_sentence_length  discourse_connective_count  vocabulary_richness  \
# 0               24.687500                           8             0.666667
# 1               22.800000                           8             0.591549
# 2               20.400000                           4             0.697674
# 3               21.333333                          11             0.656250
# 4               17.266667                           9             0.594470
# ...                   ...                         ...                  ...
# 1778            26.000000                          17             0.613445
# 1779            11.238095                           6             0.739583
# 1780            17.444444                           5             0.430769
# 1781            16.000000                           0             1.000000
# 1782            13.500000                           6             0.712963
#
#       semantic_relevance  flesch_reading_ease  flesch_kincaid_grade  \
# 0               0.835594                74.02                   8.5
# 1               0.851565                67.08                   9.1
# 2               0.891696                68.20                   8.7
# 3               0.826223                60.24                   9.7
# 4               0.868435                72.66                   7.0
# ...                  ...                  ...                   ...
# 1778            0.797401                82.38                   7.4
# 1779            0.852031                86.20                   3.8
# 1780            0.873364                71.04                   7.6
# 1781            0.670406                90.09                   4.4
# 1782            0.828526                84.88                   4.4
#
#       overall_score
# 0               8.0
# 1               9.0
# 2               7.0
# 3              10.0
# 4               8.0
# ...             ...
# 1778            8.0
# 1779            7.0
# 1780            8.0
# 1781            2.0
# 1782            7.0
#
# [1783 rows x 13 columns]

# %%
df_scaled_1 = min_max_scaling_column(df_c1, 2, 12)
df_scaled_1.to_csv("df_scaled_1_with_feature_selection.csv")
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_7256\3390416986.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["scaled_score"] = (df["overall_score"] - min_value) / (max_value - min_value)

# %%
df_scaled_2 = min_max_scaling_column(df_22, 2, 10)
df_scaled_2.to_csv("df_scaled_2_with_feature_selection.csv")
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_7256\3390416986.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["scaled_score"] = (df["overall_score"] - min_value) / (max_value - min_value)

# %%
df_scaled_3 = min_max_scaling_column(df_33, 0, 3)
df_scaled_3.to_csv("df_scaled_3_with_feature_selection.csv")
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_7256\3390416986.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["scaled_score"] = (df["overall_score"] - min_value) / (max_value - min_value)

# %%
df_scaled_4 = min_max_scaling_column(df_44, 0, 3)
df_scaled_4.to_csv("df_scaled_4_with_feature_selection.csv")
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_7256\3390416986.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["scaled_score"] = (df["overall_score"] - min_value) / (max_value - min_value)

# %%
df_scaled_5 = min_max_scaling_column(df_55, 0, 4)
df_scaled_5.to_csv("df_scaled_5_with_feature_selection.csv")
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_7256\3390416986.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["scaled_score"] = (df["overall_score"] - min_value) / (max_value - min_value)

# %%
df_scaled_6 = min_max_scaling_column(df_66, 0, 4)
df_scaled_6.to_csv("df_scaled_6_with_feature_selection.csv")
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_7256\3390416986.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["scaled_score"] = (df["overall_score"] - min_value) / (max_value - min_value)

# %%
df_scaled_7 = min_max_scaling_column(df_77, 0, 30)
df_scaled_7.to_csv("df_scaled_7_with_feature_selection.csv")
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_7256\3390416986.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["scaled_score"] = (df["overall_score"] - min_value) / (max_value - min_value)

# %%
df_scaled_8 = min_max_scaling_column(df_88, 0, 60)
df_scaled_8.to_csv("df_scaled_8_with_feature_selection.csv")
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_7256\3390416986.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["scaled_score"] = (df["overall_score"] - min_value) / (max_value - min_value)

# %%
df_scaled_8
# Out:
#      essay_id  essay_set                                              essay  \
# 0       20716          8   A long time ago when I was in third grade I h...
# 1       20717          8   Softball has to be one of the single most gre...
# 2       20718          8   Some people like making people laugh, I love ...
# 3       20719          8   "LAUGHTER"  @CAPS1 I hang out with my friends...
# 4       20721          8  Well ima tell a story about the time i got @CA...
# ..        ...        ...                                                ...
# 718     21626          8   In most stories mothers and daughters are eit...
# 719     21628          8   I never understood the meaning laughter is th...
# 720     21629          8  When you laugh, is @CAPS5 out of habit, or is ...
# 721     21630          8                                 Trippin' on fen...
# 722     21633          8   Many people believe that laughter can improve...
#
#      num_grammatical_errors  lexical_repetition_ratio  unique_lemmas_count  \
# 0                        61                  0.680272                  148
# 1                        17                  0.633898                  163
# 2                        21                  0.611446                  178
# 3                        70                  0.674699                  134
# 4                       115                  0.751825                  111
# ..                      ...                       ...                  ...
# 718                      19                  0.575472                  188
# 719                      44                  0.701357                  110
# 720                      14                  0.537143                  220
# 721                       6                  0.574766                  127
# 722                       2                  0.527638                  125
#
#      avg_sentence_length  discourse_connective_count  vocabulary_richness  \
# 0              16.954545                          13             0.520505
# 1              23.916667                          16             0.635593
# 2              23.142857                          16             0.578164
# 3              19.973684                          14             0.595070
# 4              13.018519                          17             0.522388
# ..                   ...                         ...                  ...
# 718            23.243902                          19             0.627072
# 719            16.282051                           7             0.550000
# 720            21.222222                          17             0.745509
# 721            17.076923                          21             0.663793
# 722            18.310345                           9             0.707547
#
#      semantic_relevance  flesch_reading_ease  flesch_kincaid_grade  \
# 0              0.707057                88.87                   4.9
# 1              0.777121                78.93                   8.7
# 2              0.795551                74.83                   8.2
# 3              0.737897                81.46                   7.7
# 4              0.625690                88.60                   7.1
# ..                  ...                  ...                   ...
# 718            0.794858                65.09                  12.0
# 719            0.791210                91.11                   4.0
# 720            0.766729                69.11                   8.3
# 721            0.819285                81.83                   5.5
# 722            0.863376                72.05                   7.2
#
#      overall_score  scaled_score
# 0             34.0      0.566667
# 1             46.0      0.766667
# 2             40.0      0.666667
# 3             30.0      0.500000
# 4             26.0      0.433333
# ..             ...           ...
# 718           35.0      0.583333
# 719           32.0      0.533333
# 720           40.0      0.666667
# 721           40.0      0.666667
# 722           40.0      0.666667
#
# [723 rows x 14 columns]

# %%
df_all = pd.concat([df_scaled_1, df_scaled_2, df_scaled_3, df_scaled_4, 
                    df_scaled_5, df_scaled_6, df_scaled_7, df_scaled_8], ignore_index=True)

df_all
# Out:
#        essay_id  essay_set                                              essay  \
# 0             1          1  Dear local newspaper, I think effects computer...
# 1             2          1  Dear @CAPS1 @CAPS2, I believe that using compu...
# 2             3          1  Dear, @CAPS1 @CAPS2 @CAPS3 More and more peopl...
# 3             4          1  Dear Local Newspaper, @CAPS1 I have found that...
# 4             5          1  Dear @LOCATION1, I know having computers has a...
# ...         ...        ...                                                ...
# 12973     21626          8   In most stories mothers and daughters are eit...
# 12974     21628          8   I never understood the meaning laughter is th...
# 12975     21629          8  When you laugh, is @CAPS5 out of habit, or is ...
# 12976     21630          8                                 Trippin' on fen...
# 12977     21633          8   Many people believe that laughter can improve...
#
#        num_grammatical_errors  lexical_repetition_ratio  unique_lemmas_count  \
# 0                          17                  0.523810                   95
# 1                          24                  0.606557                  105
# 2                          14                  0.508333                   75
# 3                          29                  0.600000                  155
# 4                          18                  0.631285                  102
# ...                       ...                       ...                  ...
# 12973                      19                  0.575472                  188
# 12974                      44                  0.701357                  110
# 12975                      14                  0.537143                  220
# 12976                       6                  0.574766                  127
# 12977                       2                  0.527638                  125
#
#        avg_sentence_length  discourse_connective_count  vocabulary_richness  \
# 0                24.687500                           8             0.666667
# 1                22.800000                           8             0.591549
# 2                20.400000                           4             0.697674
# 3                21.333333                          11             0.656250
# 4                17.266667                           9             0.594470
# ...                    ...                         ...                  ...
# 12973            23.243902                          19             0.627072
# 12974            16.282051                           7             0.550000
# 12975            21.222222                          17             0.745509
# 12976            17.076923                          21             0.663793
# 12977            18.310345                           9             0.707547
#
#        semantic_relevance  flesch_reading_ease  flesch_kincaid_grade  \
# 0                0.835594                74.02                   8.5
# 1                0.851565                67.08                   9.1
# 2                0.891696                68.20                   8.7
# 3                0.826223                60.24                   9.7
# 4                0.868435                72.66                   7.0
# ...                   ...                  ...                   ...
# 12973            0.794858                65.09                  12.0
# 12974            0.791210                91.11                   4.0
# 12975            0.766729                69.11                   8.3
# 12976            0.819285                81.83                   5.5
# 12977            0.863376                72.05                   7.2
#
#        overall_score  scaled_score
# 0                8.0      0.600000
# 1                9.0      0.700000
# 2                7.0      0.500000
# 3               10.0      0.800000
# 4                8.0      0.600000
# ...              ...           ...
# 12973           35.0      0.583333
# 12974           32.0      0.533333
# 12975           40.0      0.666667
# 12976           40.0      0.666667
# 12977           40.0      0.666667
#
# [12978 rows x 14 columns]

# %%
df_all.to_csv("df_all_sets_with_feature.csv")

# %%
df_all["scaled_score"].min()
# Out:
# 0.0

# %%
df_all.isna().sum()
# Out:
# essay_id                      0
# essay_set                     0
# essay                         0
# num_grammatical_errors        0
# lexical_repetition_ratio      0
# unique_lemmas_count           0
# avg_sentence_length           0
# discourse_connective_count    0
# vocabulary_richness           0
# semantic_relevance            0
# flesch_reading_ease           0
# flesch_kincaid_grade          0
# overall_score                 1
# scaled_score                  1
# dtype: int64

# %%
df_all_clean = df_all.dropna()
df_all_clean.isna().sum()
# Out:
# essay_id                      0
# essay_set                     0
# essay                         0
# num_grammatical_errors        0
# lexical_repetition_ratio      0
# unique_lemmas_count           0
# avg_sentence_length           0
# discourse_connective_count    0
# vocabulary_richness           0
# semantic_relevance            0
# flesch_reading_ease           0
# flesch_kincaid_grade          0
# overall_score                 0
# scaled_score                  0
# dtype: int64

# %%
df_all_clean.to_csv("df_all_sets_with_feature.csv")

# %%
import pandas as pd 

df = pd.read_csv("test_scores.csv")
df
# Out:
#       scaled_score  overall_score  essay_set
# 0         0.333333            1.0          3
# 1         0.750000            3.0          5
# 2         0.666667            2.0          3
# 3         0.666667            2.0          3
# 4         0.500000            6.0          2
# ...            ...            ...        ...
# 2591      0.666667            2.0          4
# 2592      1.000000            4.0          6
# 2593      0.333333            1.0          3
# 2594      0.375000            5.0          2
# 2595      0.600000            8.0          1
#
# [2596 rows x 3 columns]

# %%
import pandas as pd

# %%
scaled_test_fs = pd.read_csv("datasets_all_sets/scaled_test_fs.csv")
scaled_test_fs
# Out:
#       Unnamed: 0  num_grammatical_errors  lexical_repetition_ratio  \
# 0              0               -0.960370                 -0.188983
# 1              1               -0.563574                 -1.340225
# 2              2               -0.960370                 -0.078961
# 3              3               -0.365176                 -1.297811
# 4              4                0.626814                  0.461368
# ...          ...                     ...                       ...
# 2591        2591               -0.761972                  1.204627
# 2592        2592               -0.761972                  0.023003
# 2593        2593               -0.861171                 -1.526847
# 2594        2594                0.230018                  0.838804
# 2595        2595                2.610794                  0.697353
#
#       unique_lemmas_count  avg_sentence_length  discourse_connective_count  \
# 0               -1.103095            -0.349522                   -0.888228
# 1                0.038368             0.814219                   -1.083008
# 2               -0.798705            -0.979882                   -0.888228
# 3               -0.468949             0.853011                   -0.693448
# 4               -0.443583            -0.109721                    0.085672
# ...                   ...                  ...                         ...
# 2591            -0.747973             0.224590                   -0.109108
# 2592            -0.240657            -0.089620                   -0.109108
# 2593            -1.026998            -1.311548                   -1.083008
# 2594            -0.722608             1.271958                   -0.109108
# 2595             1.509586             0.001364                    0.864792
#
#       vocabulary_richness  semantic_relevance  flesch_reading_ease  \
# 0                0.041613           -0.479015            -0.681243
# 1                1.164794           -0.489270            -1.904258
# 2                0.277342           -0.232819             0.296853
# 3                0.905954           -1.407660            -0.774170
# 4               -0.875113            1.365502             0.475620
# ...                   ...                 ...                  ...
# 2591            -0.558830            0.612813            -0.566266
# 2592             0.382111            0.168465             0.411831
# 2593             1.314552           -1.289203             1.837237
# 2594            -0.425851            0.017702             0.142500
# 2595            -0.829561            0.300249            -0.422938
#
#       flesch_kincaid_grade
# 0                 0.004408
# 1                 1.559220
# 2                -0.695257
# 3                 0.652247
# 4                -0.384295
# ...                    ...
# 2591              0.393111
# 2592             -0.306554
# 2593             -1.576317
# 2594              0.574506
# 2595              0.211717
#
# [2596 rows x 10 columns]

# %%
test_features_all = pd.read_csv("datasets_all_sets/test_features_with_fs.csv")
test_scores_all =pd.read_csv("datasets_all_sets/test_scores_with_fs.csv")
essay = test_features_all["essay"]
result = pd.concat([essay, scaled_test_fs, test_scores_all], axis=1).drop(columns=["Unnamed: 0"])
result
# Out:
#                                                   essay  \
# 0     In the towns that the cyclist arrived at were ...
# 1          In this memoir, Narciso Rodriguez speaks ...
# 2     The features of the setting affected the cycli...
# 3     In the story ‘Do Not Exceed Posted Speed Limit...
# 4     Should materials, such as books, music, movies...
# ...                                                 ...
# 2591  The author concludes the story with a sentence...
# 2592  In the process of building the dock for dirigi...
# 2593  Almost all of the cyclist’s surroundings are o...
# 2594  I think that everyone has there own opinon in ...
# 2595  Dear @CAPS1, @CAPS2 name is @PERSON1 and I do ...
#
#       num_grammatical_errors  lexical_repetition_ratio  unique_lemmas_count  \
# 0                  -0.960370                 -0.188983            -1.103095
# 1                  -0.563574                 -1.340225             0.038368
# 2                  -0.960370                 -0.078961            -0.798705
# 3                  -0.365176                 -1.297811            -0.468949
# 4                   0.626814                  0.461368            -0.443583
# ...                      ...                       ...                  ...
# 2591               -0.761972                  1.204627            -0.747973
# 2592               -0.761972                  0.023003            -0.240657
# 2593               -0.861171                 -1.526847            -1.026998
# 2594                0.230018                  0.838804            -0.722608
# 2595                2.610794                  0.697353             1.509586
#
#       avg_sentence_length  discourse_connective_count  vocabulary_richness  \
# 0               -0.349522                   -0.888228             0.041613
# 1                0.814219                   -1.083008             1.164794
# 2               -0.979882                   -0.888228             0.277342
# 3                0.853011                   -0.693448             0.905954
# 4               -0.109721                    0.085672            -0.875113
# ...                   ...                         ...                  ...
# 2591             0.224590                   -0.109108            -0.558830
# 2592            -0.089620                   -0.109108             0.382111
# 2593            -1.311548                   -1.083008             1.314552
# 2594             1.271958                   -0.109108            -0.425851
# 2595             0.001364                    0.864792            -0.829561
#
#       semantic_relevance  flesch_reading_ease  flesch_kincaid_grade  \
# 0              -0.479015            -0.681243              0.004408
# 1              -0.489270            -1.904258              1.559220
# 2              -0.232819             0.296853             -0.695257
# 3              -1.407660            -0.774170              0.652247
# 4               1.365502             0.475620             -0.384295
# ...                  ...                  ...                   ...
# 2591            0.612813            -0.566266              0.393111
# 2592            0.168465             0.411831             -0.306554
# 2593           -1.289203             1.837237             -1.576317
# 2594            0.017702             0.142500              0.574506
# 2595            0.300249            -0.422938              0.211717
#
#       scaled_score  overall_score  essay_set  essay_id
# 0         0.333333            1.0          3      7398
# 1         0.750000            3.0          5     13472
# 2         0.666667            2.0          3      7004
# 3         0.666667            2.0          3      6790
# 4         0.500000            6.0          2      4599
# ...            ...            ...        ...       ...
# 2591      0.666667            2.0          4      9600
# 2592      1.000000            4.0          6     15200
# 2593      0.333333            1.0          3      6256
# 2594      0.375000            5.0          2      4509
# 2595      0.600000            8.0          1        80
#
# [2596 rows x 14 columns]

# %%
essay_set_totals = {
    1: 12,
    2: 10,
    3: 3,
    4: 3,
    5: 4,
    6: 4,
    7: 30,
    8: 60
}

# %%
result['total_score'] = result['essay_set'].map(essay_set_totals)
result.to_csv("test_allsets.csv")

# %%
result['overall_score'] = result['overall_score'].astype(int)
result
# Out:
#                                                   essay  \
# 0     In the towns that the cyclist arrived at were ...
# 1          In this memoir, Narciso Rodriguez speaks ...
# 2     The features of the setting affected the cycli...
# 3     In the story ‘Do Not Exceed Posted Speed Limit...
# 4     Should materials, such as books, music, movies...
# ...                                                 ...
# 2591  The author concludes the story with a sentence...
# 2592  In the process of building the dock for dirigi...
# 2593  Almost all of the cyclist’s surroundings are o...
# 2594  I think that everyone has there own opinon in ...
# 2595  Dear @CAPS1, @CAPS2 name is @PERSON1 and I do ...
#
#       num_grammatical_errors  lexical_repetition_ratio  unique_lemmas_count  \
# 0                  -0.960370                 -0.188983            -1.103095
# 1                  -0.563574                 -1.340225             0.038368
# 2                  -0.960370                 -0.078961            -0.798705
# 3                  -0.365176                 -1.297811            -0.468949
# 4                   0.626814                  0.461368            -0.443583
# ...                      ...                       ...                  ...
# 2591               -0.761972                  1.204627            -0.747973
# 2592               -0.761972                  0.023003            -0.240657
# 2593               -0.861171                 -1.526847            -1.026998
# 2594                0.230018                  0.838804            -0.722608
# 2595                2.610794                  0.697353             1.509586
#
#       avg_sentence_length  discourse_connective_count  vocabulary_richness  \
# 0               -0.349522                   -0.888228             0.041613
# 1                0.814219                   -1.083008             1.164794
# 2               -0.979882                   -0.888228             0.277342
# 3                0.853011                   -0.693448             0.905954
# 4               -0.109721                    0.085672            -0.875113
# ...                   ...                         ...                  ...
# 2591             0.224590                   -0.109108            -0.558830
# 2592            -0.089620                   -0.109108             0.382111
# 2593            -1.311548                   -1.083008             1.314552
# 2594             1.271958                   -0.109108            -0.425851
# 2595             0.001364                    0.864792            -0.829561
#
#       semantic_relevance  flesch_reading_ease  flesch_kincaid_grade  \
# 0              -0.479015            -0.681243              0.004408
# 1              -0.489270            -1.904258              1.559220
# 2              -0.232819             0.296853             -0.695257
# 3              -1.407660            -0.774170              0.652247
# 4               1.365502             0.475620             -0.384295
# ...                  ...                  ...                   ...
# 2591            0.612813            -0.566266              0.393111
# 2592            0.168465             0.411831             -0.306554
# 2593           -1.289203             1.837237             -1.576317
# 2594            0.017702             0.142500              0.574506
# 2595            0.300249            -0.422938              0.211717
#
#       scaled_score  overall_score  essay_set  essay_id  total_score
# 0         0.333333              1          3      7398            3
# 1         0.750000              3          5     13472            4
# 2         0.666667              2          3      7004            3
# 3         0.666667              2          3      6790            3
# 4         0.500000              6          2      4599           10
# ...            ...            ...        ...       ...          ...
# 2591      0.666667              2          4      9600            3
# 2592      1.000000              4          6     15200            4
# 2593      0.333333              1          3      6256            3
# 2594      0.375000              5          2      4509           10
# 2595      0.600000              8          1        80           12
#
# [2596 rows x 15 columns]

# %%
result.to_csv("test_allsets.csv")

# %%
df_all = pd.read_csv("df_all.csv")
df_all.head(10).to_csv("test.csv")

# %%
result.columns
# Out:
# Index(['essay', 'num_grammatical_errors', 'lexical_repetition_ratio',
#        'unique_lemmas_count', 'avg_sentence_length',
#        'discourse_connective_count', 'vocabulary_richness',
#        'semantic_relevance', 'flesch_reading_ease', 'flesch_kincaid_grade',
#        'scaled_score', 'overall_score', 'essay_set', 'essay_id',
#        'total_score'],
#       dtype='object')

# %%
df_all['total_score'] = df_all['essay_set'].map(essay_set_totals)
df_all
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df_all['total_score'] = df_all['essay_set'].map(essay_set_totals)
#       2 df_all
#
# NameError: name 'df_all' is not defined

# %%
df_all['overall_score'] = df_all['overall_score'].astype(int)
df_all.to_csv("test.csv")

# %%
df = pd.read_csv("test_allsets.csv")
df = df.drop(columns=["Unnamed: 0"]).head(20)
df
# Out:
#                                                 essay  num_grammatical_errors  \
# 0   In the towns that the cyclist arrived at were ...               -0.960370
# 1        In this memoir, Narciso Rodriguez speaks ...               -0.563574
# 2   The features of the setting affected the cycli...               -0.960370
# 3   In the story ‘Do Not Exceed Posted Speed Limit...               -0.365176
# 4   Should materials, such as books, music, movies...                0.626814
# 5                                  Trippin' on fen...               -0.365176
# 6   Wouldn't you agree that computers have a great...                1.222008
# 7    Laughter is the expression of being happy, be...                1.122809
# 8   I think that @CAPS4 is fine if you take them o...                0.428416
# 9   I feel that books, music, movies, and magazine...                1.023610
# 10  Dear @CITY1 @ORGANIZATION1, I am a @ORGANIZATI...                0.130819
# 11  When most people think of patience they think ...                0.031620
# 12  Dear reader, @ORGANIZATION1 has had a dramatic...                0.230018
# 13  Do you like computers? Do you use the internet...                0.726013
# 14  The author generally stayed in one mood. The m...               -0.067579
# 15  In the short story “Winter Hibiscus”, the auth...               -0.166778
# 16  Books, movies, magazines, music, etc., make up...                0.527615
# 17  Me and my brother have been asking for a dog f...                0.527615
# 18  The cyclist trusted a man that didn`t know muc...               -0.365176
# 19  The features of the setting affect the cyclist...               -0.861171
#
#     lexical_repetition_ratio  unique_lemmas_count  avg_sentence_length  \
# 0                  -0.188983            -1.103095            -0.349522
# 1                  -1.340225             0.038368             0.814219
# 2                  -0.078961            -0.798705            -0.979882
# 3                  -1.297811            -0.468949             0.853011
# 4                   0.461368            -0.443583            -0.109721
# 5                   0.666719             1.737879            -0.418153
# 6                   1.237695             0.748611             0.099109
# 7                   1.210982             2.676415             0.225726
# 8                   1.492850            -0.342120            -0.646162
# 9                   1.307314            -0.164559            -1.168990
# 10                  0.814416             0.139831            -0.379186
# 11                 -1.179994            -0.316754            -0.491757
# 12                  0.146428             1.560318            -0.723028
# 13                  0.139052             0.773977            -0.767607
# 14                 -0.312859            -0.418218             0.321015
# 15                  0.161040             0.697880            -0.056162
# 16                  1.791596             0.951538             0.802413
# 17                 -0.103466             0.063733             0.090113
# 18                 -0.551321            -0.291388             0.121516
# 19                  0.082771            -0.747973            -0.031433
#
#     discourse_connective_count  vocabulary_richness  semantic_relevance  \
# 0                    -0.888228             0.041613           -0.479015
# 1                    -1.083008             1.164794           -0.489270
# 2                    -0.888228             0.277342           -0.232819
# 3                    -0.693448             0.905954           -1.407660
# 4                     0.085672            -0.875113            1.365502
# 5                     3.007372            -0.689961            0.415619
# 6                     3.786492            -1.670717            1.053584
# 7                     4.760392            -1.051673           -0.284145
# 8                     1.059572            -0.456038            0.036687
# 9                     0.085672            -1.177159            0.832781
# 10                    0.085672            -0.810640            0.987680
# 11                   -0.109108             1.431604           -0.294856
# 12                   -0.303888            -0.386684            1.128700
# 13                    1.254352            -0.443713            0.646820
# 14                   -0.693448             0.748801           -0.962715
# 15                    1.838692            -0.217859            0.921705
# 16                    1.059572            -2.031181            1.353657
# 17                   -0.693448            -0.697359           -1.133066
# 18                   -0.498668             0.596484           -1.714472
# 19                   -0.888228            -0.135184           -0.438620
#
#     flesch_reading_ease  flesch_kincaid_grade  scaled_score  overall_score  \
# 0             -0.681243              0.004408      0.333333              1
# 1             -1.904258              1.559220      0.750000              3
# 2              0.296853             -0.695257      0.666667              2
# 3             -0.774170              0.652247      0.666667              2
# 4              0.475620             -0.384295      0.500000              6
# 5              0.611073             -0.565689      0.666667             40
# 6             -0.446563              0.237630      0.700000              9
# 7              0.051935              0.159890      0.600000             36
# 8              1.333226             -0.928479      0.375000              5
# 9              1.042632             -1.109873      0.500000              6
# 10             0.355917             -0.228813      0.600000              8
# 11             0.770939             -0.772997      0.600000             18
# 12             0.121237             -0.487949      0.700000              9
# 13             0.065323             -0.410208      0.700000              9
# 14             0.331504             -0.202900      0.750000              3
# 15             0.363792             -0.254727      1.000000              3
# 16            -1.882995              0.989122      0.625000              7
# 17             0.629973             -0.047419      0.566667             17
# 18             0.203926             -0.047419      0.666667              2
# 19             0.259840             -0.125159      0.333333              1
#
#     essay_set  essay_id  total_score
# 0           3      7398            3
# 1           5     13472            4
# 2           3      7004            3
# 3           3      6790            3
# 4           2      4599           10
# 5           8     21630           60
# 6           1      1710           12
# 7           8     21424           60
# 8           2      4327           10
# 9           2      4119           10
# 10          1      1580           12
# 11          7     18647           30
# 12          1         9           12
# 13          1      1241           12
# 14          5     11836            4
# 15          4      9442            3
# 16          2      4768           10
# 17          7     19090           30
# 18          3      6102            3
# 19          3      6010            3

# %%
df.to_csv('testfile.csv')
